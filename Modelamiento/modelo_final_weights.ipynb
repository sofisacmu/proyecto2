# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
def create_improved_model(input_dim):
    """
    Crear un modelo mejorado
    """
    model = Sequential([
        Dense(64, activation='relu', input_dim=input_dim,
              kernel_initializer='glorot_uniform'),
        Dropout(0.3),
        Dense(32, activation='relu',
              kernel_initializer='glorot_uniform'),
        Dropout(0.3),
        Dense(1, activation='sigmoid',
              kernel_initializer='glorot_uniform')
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
def train_and_evaluate_model(model, X_train, y_train, X_test, y_test, class_weights, model_name="Modelo"):
    """
    Entrenar y evaluar modelo
    """
    print(f"Entrenando {model_name}")
    
    # Callbacks para monitorear el entrenamiento
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', 
        factor=0.2, 
        patience=10, 
        min_lr=0.0001,
        verbose=1
    )
    
    # Entrenar modelo
    history = model.fit(
        X_train, y_train,
        class_weight=class_weights, 
        validation_data=(X_test, y_test),
        epochs=50,
        batch_size=32,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    
    # Evaluar modelo
    print(f"\nEvluación {model_name}")
    
    # Predicciones
    y_pred_prob = model.predict(X_test, verbose=0)
    y_pred = (y_pred_prob > 0.5).astype(int).flatten()
    
    # Estadísticas de probabilidades
    print(f"Estadísticas de probabilidades:")
    print(f"  Min: {y_pred_prob.min():.6f}")
    print(f"  Max: {y_pred_prob.max():.6f}")
    print(f"  Mean: {y_pred_prob.mean():.6f}")
    print(f"  Std: {y_pred_prob.std():.6f}")
    print(f"  Mediana: {np.median(y_pred_prob):.6f}")
    
    # Distribución de predicciones
    print(f"\nDistribución de predicciones:")
    unique, counts = np.unique(y_pred, return_counts=True)
    for val, count in zip(unique, counts):
        label = "exitoso" if val == 1 else "no_exitoso"
        print(f"  {label}: {count}")
    
    # Matriz de confusión
    print(f"\nMatriz de confusión:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    
    # Reporte de clasificación
    print(f"\nReporte de clasificación:")
    print(classification_report(y_test, y_pred, target_names=['no_exitoso', 'exitoso']))
    
    # Verificar pesos del modelo
    print(f"\nAnálisis de pesos:")
    for i, layer in enumerate(model.layers):
        if hasattr(layer, 'get_weights') and layer.get_weights():
            weights = layer.get_weights()[0]
            print(f"  Capa {i}: shape={weights.shape}, rango=[{weights.min():.6f}, {weights.max():.6f}]")
    
    return history, y_pred_prob

# %%
# Cargar datos
df = pd.read_csv("C:/Users/sofia/Downloads/Repositorios analítica/analítica/proyecto2/Datos/Datos2011Limipios.csv")
print(f"Datos originales: {df.shape}")
print(f"Distribución original:\n{df['resultado'].value_counts()}")
# Out:
# Datos originales: (494094, 29)
# Distribución original:
# resultado
# no_exitoso    476685
# exitoso        17409
# Name: count, dtype: int64

# %%
categorical_columns = ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 
                       'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
existing_categorical = [col for col in categorical_columns if col in df.columns]
print(f"Columnas categóricas disponibles: {existing_categorical}")
# Out:
# Columnas categóricas disponibles: ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
df_processed = df.copy()

# %%
encoders = {}
for col in existing_categorical:
    print(f"Procesando {col}...")
    # Llenar valores nulos
    df_processed[col] = df_processed[col].fillna('unknown')
    
    # Codificar con LabelEncoder
    le = LabelEncoder()
    df_processed[col] = le.fit_transform(df_processed[col].astype(str))
    encoders[col] = le
    
    print(f"  {col}: {len(le.classes_)} clases únicas")
# Out:
# Procesando cole_depto_ubicacion...
#   cole_depto_ubicacion: 34 clases únicas
# Procesando cole_jornada...
#   cole_jornada: 6 clases únicas
# Procesando cole_naturaleza...
#   cole_naturaleza: 2 clases únicas
# Procesando fami_educacionmadre...
#   fami_educacionmadre: 11 clases únicas
# Procesando fami_educacionpadre...
#   fami_educacionpadre: 11 clases únicas
# Procesando fami_estratovivienda...
#   fami_estratovivienda: 6 clases únicas

# %%
feature_columns = existing_categorical
X = df_processed[feature_columns].copy()
y = df_processed['resultado'].map({'no_exitoso': 0, 'exitoso': 1})

print(f"\nFeatures finales: {X.shape}")
print(f"Columnas: {list(X.columns)}")
# Out:
# Features finales: (494094, 6)
# Columnas: ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
from sklearn.utils import class_weight
# Asignación de pesos a las clases para evitar el sesgo
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y), y=y)
class_weights = {cls: weight for cls, weight in zip(np.unique(y), weights)}
class_weights
# Out:
# {np.int64(0): np.float64(0.5182604864847855),
#  np.int64(1): np.float64(14.190763398242288)}

# %%
scaler = StandardScaler()
X_scaled = pd.DataFrame(
    scaler.fit_transform(X), 
    columns=X.columns, 
    index=X.index
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print(f"\nConjuntos de entrenamiento y prueba:")
print(f"  Train: {X_train.shape}, distribución: {np.bincount(y_train)}")
print(f"  Test: {X_test.shape}, distribución: {np.bincount(y_test)}")
# Out:
# Conjuntos de entrenamiento y prueba:
#   Train: (395275, 6), distribución: [381348  13927]
#   Test: (98819, 6), distribución: [95337  3482]

# %%
improved_model = create_improved_model(X_train.shape[1])
improved_history, improved_probs = train_and_evaluate_model(
    improved_model, X_train, y_train, X_test, y_test, class_weights, "Mejorado"
)
    
# Guardar el mejor modelo
best_model = improved_model
best_probs = improved_probs
# Out:
# c:\Users\sofia\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Entrenando Mejorado
# Epoch 1/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - accuracy: 0.8421 - loss: 0.3851 - val_accuracy: 0.8635 - val_loss: 0.3210 - learning_rate: 0.0010
# Epoch 2/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8571 - loss: 0.3607 - val_accuracy: 0.8643 - val_loss: 0.3190 - learning_rate: 0.0010
# Epoch 3/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8629 - loss: 0.3553 - val_accuracy: 0.8593 - val_loss: 0.3414 - learning_rate: 0.0010
# Epoch 4/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8639 - loss: 0.3586 - val_accuracy: 0.8702 - val_loss: 0.3238 - learning_rate: 0.0010
# Epoch 5/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8637 - loss: 0.3555 - val_accuracy: 0.8535 - val_loss: 0.4104 - learning_rate: 0.0010
# Epoch 6/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8615 - loss: 0.3610 - val_accuracy: 0.8503 - val_loss: 0.3736 - learning_rate: 0.0010
# Epoch 7/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8635 - loss: 0.3527 - val_accuracy: 0.8549 - val_loss: 0.3405 - learning_rate: 0.0010
# Epoch 8/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8640 - loss: 0.3549 - val_accuracy: 0.8449 - val_loss: 0.3515 - learning_rate: 0.0010
# Epoch 9/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.8601 - loss: 0.3552 - val_accuracy: 0.8545 - val_loss: 0.3653 - learning_rate: 0.0010
# Epoch 10/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - accuracy: 0.8655 - loss: 0.3576 - val_accuracy: 0.8529 - val_loss: 0.3541 - learning_rate: 0.0010
# Epoch 11/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - accuracy: 0.8634 - loss: 0.3521 - val_accuracy: 0.8574 - val_loss: 0.3749 - learning_rate: 0.0010
# Epoch 12/50
# 12337/12353 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8640 - loss: 0.3550
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 62s 5ms/step - accuracy: 0.8640 - loss: 0.3550 - val_accuracy: 0.8538 - val_loss: 0.3703 - learning_rate: 0.0010
# Epoch 13/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - accuracy: 0.8642 - loss: 0.3497 - val_accuracy: 0.8637 - val_loss: 0.3274 - learning_rate: 2.0000e-04
# Epoch 14/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 35s 3ms/step - accuracy: 0.8659 - loss: 0.3462 - val_accuracy: 0.8561 - val_loss: 0.3406 - learning_rate: 2.0000e-04
# Epoch 15/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 35s 3ms/step - accuracy: 0.8615 - loss: 0.3503 - val_accuracy: 0.8580 - val_loss: 0.3430 - learning_rate: 2.0000e-04
# Epoch 16/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 35s 3ms/step - accuracy: 0.8618 - loss: 0.3497 - val_accuracy: 0.8631 - val_loss: 0.3292 - learning_rate: 2.0000e-04
# Epoch 17/50
# 12353/12353 ━━━━━━━━━━━━━━━━━━━━ 35s 3ms/step - accuracy: 0.8650 - loss: 0.3495 - val_accuracy: 0.8573 - val_loss: 0.3405 - learning_rate: 2.0000e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 2.
#
# Evluación Mejorado
# Estadísticas de probabilidades:
#   Min: 0.003103
#   Max: 0.992607
#   Mean: 0.214046
#   Std: 0.266935
#   Mediana: 0.089043
#
# Distribución de predicciones:
#   no_exitoso: 83019
#   exitoso: 15800
#
# Matriz de confusión:
# [[82472 12865]
#  [  547  2935]]
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#   no_exitoso       0.99      0.87      0.92     95337
#      exitoso       0.19      0.84      0.30      3482
#
#     accuracy                           0.86     98819
#    macro avg       0.59      0.85      0.61     98819
# weighted avg       0.96      0.86      0.90     98819
#
#
# Análisis de pesos:
#   Capa 0: shape=(6, 64), rango=[-0.561213, 0.576389]
#   Capa 2: shape=(64, 32), rango=[-1.134538, 0.521278]
#   Capa 4: shape=(32, 1), rango=[-0.261235, 0.158566]

# %%
best_model.save('modelo_final.keras')
# Guardar información de preprocesamiento
import pickle
preprocessing_info = {
    'feature_columns': feature_columns,
    'encoders': encoders,
    'scaler': scaler,
    'categorical_columns': existing_categorical
    }
    
with open('preprocessing_info.pkl', 'wb') as f:
    pickle.dump(preprocessing_info, f)

# %%
def test_predictions_on_sample(model_path, preprocessing_path, sample_data):
    """
    Probar predicciones en datos de muestra
    """
    model = tf.keras.models.load_model(model_path)
    
    with open(preprocessing_path, 'rb') as f:
        prep_info = pickle.load(f)
    
    # Procesar datos
    sample_processed = sample_data.copy()
    
    for col in prep_info['categorical_columns']:
        if col in sample_processed.columns:
            sample_processed[col] = sample_processed[col].fillna('unknown')
            le = prep_info['encoders'][col]
            # Manejar valores no vistos
            sample_processed[col] = sample_processed[col].astype(str).apply(
                lambda x: x if x in le.classes_ else le.classes_[0]
            )
            sample_processed[col] = le.transform(sample_processed[col])
    
    # Normalizar
    sample_scaled = prep_info['scaler'].transform(sample_processed[prep_info['feature_columns']])
    
    # Predecir
    probs = model.predict(sample_scaled, verbose=0)
    preds = (probs > 0.5).astype(int)
    
    return probs, preds

# %%
sample_data = df[existing_categorical].iloc[:100]
    
try:
    probs, preds = test_predictions_on_sample(
        'modelo_final.keras',
        'preprocessing_info.pkl',
        sample_data
        )
        
    print("Predicciones en muestra:")
    for i, (prob, pred) in enumerate(zip(probs.flatten(), preds.flatten())):
        real = df['resultado'].iloc[i]
        pred_label = 'exitoso' if pred == 1 else 'no_exitoso'
        print(f"  Ejemplo {i+1}: {pred_label} (prob: {prob:.4f}), Real: {real}")
            
except Exception as e:
    print(f"Error al probar predicciones: {e}")
# Out:
# Predicciones en muestra:
#   Ejemplo 1: no_exitoso (prob: 0.0648), Real: no_exitoso
#   Ejemplo 2: no_exitoso (prob: 0.0215), Real: no_exitoso
#   Ejemplo 3: no_exitoso (prob: 0.2272), Real: no_exitoso
#   Ejemplo 4: no_exitoso (prob: 0.1194), Real: no_exitoso
#   Ejemplo 5: no_exitoso (prob: 0.0946), Real: no_exitoso
#   Ejemplo 6: no_exitoso (prob: 0.2826), Real: no_exitoso
#   Ejemplo 7: no_exitoso (prob: 0.1929), Real: no_exitoso
#   Ejemplo 8: no_exitoso (prob: 0.0207), Real: no_exitoso
#   Ejemplo 9: no_exitoso (prob: 0.0086), Real: no_exitoso
#   Ejemplo 10: no_exitoso (prob: 0.1075), Real: no_exitoso
#   Ejemplo 11: no_exitoso (prob: 0.0141), Real: no_exitoso
#   Ejemplo 12: no_exitoso (prob: 0.0397), Real: no_exitoso
#   Ejemplo 13: no_exitoso (prob: 0.0143), Real: no_exitoso
#   Ejemplo 14: no_exitoso (prob: 0.0522), Real: no_exitoso
#   Ejemplo 15: exitoso (prob: 0.5587), Real: no_exitoso
#   Ejemplo 16: exitoso (prob: 0.8392), Real: exitoso
#   Ejemplo 17: no_exitoso (prob: 0.1014), Real: no_exitoso
#   Ejemplo 18: no_exitoso (prob: 0.4671), Real: no_exitoso
#   Ejemplo 19: no_exitoso (prob: 0.0154), Real: no_exitoso
#   Ejemplo 20: no_exitoso (prob: 0.0261), Real: no_exitoso
#   Ejemplo 21: no_exitoso (prob: 0.0275), Real: no_exitoso
#   Ejemplo 22: no_exitoso (prob: 0.1109), Real: no_exitoso
#   Ejemplo 23: no_exitoso (prob: 0.0381), Real: no_exitoso
#   Ejemplo 24: no_exitoso (prob: 0.2591), Real: no_exitoso
#   Ejemplo 25: exitoso (prob: 0.7471), Real: exitoso
#   Ejemplo 26: no_exitoso (prob: 0.0048), Real: no_exitoso
#   Ejemplo 27: no_exitoso (prob: 0.0627), Real: no_exitoso
#   Ejemplo 28: no_exitoso (prob: 0.1599), Real: no_exitoso
#   Ejemplo 29: no_exitoso (prob: 0.0081), Real: no_exitoso
#   Ejemplo 30: exitoso (prob: 0.7873), Real: no_exitoso
#   Ejemplo 31: no_exitoso (prob: 0.0543), Real: no_exitoso
#   Ejemplo 32: no_exitoso (prob: 0.3732), Real: no_exitoso
#   Ejemplo 33: no_exitoso (prob: 0.1182), Real: no_exitoso
#   Ejemplo 34: no_exitoso (prob: 0.0829), Real: no_exitoso
#   Ejemplo 35: no_exitoso (prob: 0.2712), Real: no_exitoso
#   Ejemplo 36: no_exitoso (prob: 0.0151), Real: no_exitoso
#   Ejemplo 37: no_exitoso (prob: 0.1339), Real: no_exitoso
#   Ejemplo 38: exitoso (prob: 0.7491), Real: no_exitoso
#   Ejemplo 39: exitoso (prob: 0.8051), Real: no_exitoso
#   Ejemplo 40: no_exitoso (prob: 0.1584), Real: no_exitoso
#   Ejemplo 41: no_exitoso (prob: 0.2465), Real: no_exitoso
#   Ejemplo 42: no_exitoso (prob: 0.3532), Real: no_exitoso
#   Ejemplo 43: no_exitoso (prob: 0.2111), Real: no_exitoso
#   Ejemplo 44: no_exitoso (prob: 0.0751), Real: no_exitoso
#   Ejemplo 45: exitoso (prob: 0.9659), Real: no_exitoso
#   Ejemplo 46: exitoso (prob: 0.6339), Real: no_exitoso
#   Ejemplo 47: no_exitoso (prob: 0.1470), Real: no_exitoso
#   Ejemplo 48: no_exitoso (prob: 0.2592), Real: no_exitoso
#   Ejemplo 49: no_exitoso (prob: 0.3630), Real: no_exitoso
#   Ejemplo 50: exitoso (prob: 0.6235), Real: no_exitoso
#   Ejemplo 51: no_exitoso (prob: 0.0455), Real: no_exitoso
#   Ejemplo 52: no_exitoso (prob: 0.3661), Real: no_exitoso
#   Ejemplo 53: no_exitoso (prob: 0.2322), Real: no_exitoso
#   Ejemplo 54: no_exitoso (prob: 0.0467), Real: no_exitoso
#   Ejemplo 55: no_exitoso (prob: 0.0133), Real: no_exitoso
#   Ejemplo 56: no_exitoso (prob: 0.0200), Real: no_exitoso
#   Ejemplo 57: no_exitoso (prob: 0.0911), Real: no_exitoso
#   Ejemplo 58: no_exitoso (prob: 0.1117), Real: no_exitoso
#   Ejemplo 59: no_exitoso (prob: 0.2570), Real: no_exitoso
#   Ejemplo 60: no_exitoso (prob: 0.0881), Real: no_exitoso
#   Ejemplo 61: no_exitoso (prob: 0.1890), Real: no_exitoso
#   Ejemplo 62: no_exitoso (prob: 0.3810), Real: no_exitoso
#   Ejemplo 63: no_exitoso (prob: 0.0433), Real: no_exitoso
#   Ejemplo 64: no_exitoso (prob: 0.1184), Real: no_exitoso
#   Ejemplo 65: no_exitoso (prob: 0.0897), Real: no_exitoso
#   Ejemplo 66: no_exitoso (prob: 0.0096), Real: no_exitoso
#   Ejemplo 67: no_exitoso (prob: 0.0714), Real: no_exitoso
#   Ejemplo 68: no_exitoso (prob: 0.1145), Real: no_exitoso
#   Ejemplo 69: no_exitoso (prob: 0.0066), Real: no_exitoso
#   Ejemplo 70: no_exitoso (prob: 0.0956), Real: no_exitoso
#   Ejemplo 71: no_exitoso (prob: 0.3789), Real: no_exitoso
#   Ejemplo 72: no_exitoso (prob: 0.0637), Real: no_exitoso
#   Ejemplo 73: no_exitoso (prob: 0.2218), Real: no_exitoso
#   Ejemplo 74: no_exitoso (prob: 0.1226), Real: no_exitoso
#   Ejemplo 75: no_exitoso (prob: 0.4360), Real: no_exitoso
#   Ejemplo 76: no_exitoso (prob: 0.0317), Real: no_exitoso
#   Ejemplo 77: exitoso (prob: 0.6923), Real: no_exitoso
#   Ejemplo 78: no_exitoso (prob: 0.2042), Real: no_exitoso
#   Ejemplo 79: no_exitoso (prob: 0.4385), Real: no_exitoso
#   Ejemplo 80: no_exitoso (prob: 0.0118), Real: no_exitoso
#   Ejemplo 81: no_exitoso (prob: 0.1553), Real: no_exitoso
#   Ejemplo 82: no_exitoso (prob: 0.3751), Real: no_exitoso
#   Ejemplo 83: no_exitoso (prob: 0.0083), Real: no_exitoso
#   Ejemplo 84: no_exitoso (prob: 0.2763), Real: no_exitoso
#   Ejemplo 85: no_exitoso (prob: 0.0158), Real: no_exitoso
#   Ejemplo 86: no_exitoso (prob: 0.1149), Real: no_exitoso
#   Ejemplo 87: exitoso (prob: 0.5096), Real: no_exitoso
#   Ejemplo 88: no_exitoso (prob: 0.0466), Real: no_exitoso
#   Ejemplo 89: no_exitoso (prob: 0.1443), Real: no_exitoso
#   Ejemplo 90: no_exitoso (prob: 0.1354), Real: no_exitoso
#   Ejemplo 91: no_exitoso (prob: 0.2186), Real: no_exitoso
#   Ejemplo 92: no_exitoso (prob: 0.1159), Real: no_exitoso
#   Ejemplo 93: no_exitoso (prob: 0.0652), Real: no_exitoso
#   Ejemplo 94: no_exitoso (prob: 0.0148), Real: no_exitoso
#   Ejemplo 95: no_exitoso (prob: 0.4666), Real: no_exitoso
#   Ejemplo 96: no_exitoso (prob: 0.0652), Real: no_exitoso
#   Ejemplo 97: no_exitoso (prob: 0.0742), Real: no_exitoso
#   Ejemplo 98: no_exitoso (prob: 0.0146), Real: no_exitoso
#   Ejemplo 99: no_exitoso (prob: 0.1592), Real: no_exitoso
#   Ejemplo 100: no_exitoso (prob: 0.0750), Real: no_exitoso

# %%
df[categorical_columns+['resultado']].iloc[:30]
# Out:
#    cole_depto_ubicacion cole_jornada cole_naturaleza  \
# 0          CUNDINAMARCA       MAÑANA         OFICIAL
# 1                 CAUCA       MAÑANA         OFICIAL
# 2                BOGOTA       MAÑANA         OFICIAL
# 3             ANTIOQUIA       MAÑANA         OFICIAL
# 4                 VALLE       MAÑANA         OFICIAL
# 5                BOGOTA     COMPLETA      NO OFICIAL
# 6                 VALLE       MAÑANA         OFICIAL
# 7               QUINDIO       MAÑANA         OFICIAL
# 8             ANTIOQUIA        TARDE         OFICIAL
# 9          CUNDINAMARCA       MAÑANA         OFICIAL
# 10               NARIÑO       MAÑANA         OFICIAL
# 11            ANTIOQUIA        TARDE         OFICIAL
# 12            ATLANTICO       MAÑANA         OFICIAL
# 13               BOGOTA        TARDE         OFICIAL
# 14                CESAR       MAÑANA      NO OFICIAL
# 15               BOGOTA     COMPLETA      NO OFICIAL
# 16                 META       MAÑANA         OFICIAL
# 17            MAGDALENA       MAÑANA         OFICIAL
# 18      NORTE SANTANDER       MAÑANA         OFICIAL
# 19               BOGOTA        NOCHE      NO OFICIAL
# 20                 META       MAÑANA         OFICIAL
# 21              QUINDIO       MAÑANA         OFICIAL
# 22               NARIÑO       MAÑANA         OFICIAL
# 23               BOGOTA        TARDE         OFICIAL
# 24               BOGOTÁ     COMPLETA      NO OFICIAL
# 25            ANTIOQUIA        TARDE         OFICIAL
# 26               ARAUCA       MAÑANA         OFICIAL
# 27            RISARALDA     COMPLETA         OFICIAL
# 28               BOYACA     SABATINA         OFICIAL
# 29            RISARALDA       MAÑANA      NO OFICIAL
#
#                      fami_educacionmadre  \
# 0                      Primaria completa
# 1   Secundaria (Bachillerato) incompleta
# 2     Secundaria (Bachillerato) completa
# 3   Secundaria (Bachillerato) incompleta
# 4                    Primaria incompleta
# 5     Secundaria (Bachillerato) completa
# 6     Secundaria (Bachillerato) completa
# 7     Secundaria (Bachillerato) completa
# 8     Secundaria (Bachillerato) completa
# 9   Secundaria (Bachillerato) incompleta
# 10                   Primaria incompleta
# 11    Secundaria (Bachillerato) completa
# 12    Secundaria (Bachillerato) completa
# 13                     Primaria completa
# 14        Educación profesional completa
# 15        Educación profesional completa
# 16  Secundaria (Bachillerato) incompleta
# 17    Secundaria (Bachillerato) completa
# 18                   Primaria incompleta
# 19                     Primaria completa
# 20                   Primaria incompleta
# 21                     Primaria completa
# 22  Secundaria (Bachillerato) incompleta
# 23  Secundaria (Bachillerato) incompleta
# 24        Técnica o tecnológica completa
# 25                     Primaria completa
# 26                   Primaria incompleta
# 27                   Primaria incompleta
# 28                   Primaria incompleta
# 29        Educación profesional completa
#
#                      fami_educacionpadre fami_estratovivienda   resultado
# 0                      Primaria completa            Estrato 2  no_exitoso
# 1     Secundaria (Bachillerato) completa            Estrato 1  no_exitoso
# 2         Educación profesional completa            Estrato 2  no_exitoso
# 3                                Ninguno            Estrato 2  no_exitoso
# 4                    Primaria incompleta            Estrato 2  no_exitoso
# 5     Secundaria (Bachillerato) completa            Estrato 2  no_exitoso
# 6         Técnica o tecnológica completa            Estrato 2  no_exitoso
# 7                    Primaria incompleta            Estrato 1  no_exitoso
# 8     Secundaria (Bachillerato) completa            Estrato 1  no_exitoso
# 9                    Primaria incompleta            Estrato 2  no_exitoso
# 10                               No sabe            Estrato 1  no_exitoso
# 11                     Primaria completa            Estrato 2  no_exitoso
# 12    Secundaria (Bachillerato) completa            Estrato 1  no_exitoso
# 13  Secundaria (Bachillerato) incompleta            Estrato 2  no_exitoso
# 14    Secundaria (Bachillerato) completa            Estrato 2  no_exitoso
# 15        Educación profesional completa            Estrato 3     exitoso
# 16                     Primaria completa            Estrato 2  no_exitoso
# 17        Educación profesional completa            Estrato 3  no_exitoso
# 18                     Primaria completa            Estrato 1  no_exitoso
# 19                     Primaria completa            Estrato 1  no_exitoso
# 20  Secundaria (Bachillerato) incompleta            Estrato 1  no_exitoso
# 21    Secundaria (Bachillerato) completa            Estrato 2  no_exitoso
# 22  Secundaria (Bachillerato) incompleta            Estrato 1  no_exitoso
# 23  Secundaria (Bachillerato) incompleta            Estrato 3  no_exitoso
# 24        Educación profesional completa            Estrato 3     exitoso
# 25                     Primaria completa            Estrato 1  no_exitoso
# 26                   Primaria incompleta            Estrato 2  no_exitoso
# 27  Secundaria (Bachillerato) incompleta            Estrato 2  no_exitoso
# 28                   Primaria incompleta            Estrato 1  no_exitoso
# 29        Educación profesional completa            Estrato 3  no_exitoso
