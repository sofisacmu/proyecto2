# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
def create_improved_model(input_dim):
    """
    Crear un modelo mejorado con mejores prácticas
    """
    model = Sequential([
        Dense(64, activation='relu', input_dim=input_dim,
              kernel_initializer='glorot_uniform'),
        Dropout(0.3),
        Dense(32, activation='relu',
              kernel_initializer='glorot_uniform'),
        Dropout(0.3),
        Dense(1, activation='sigmoid',
              kernel_initializer='glorot_uniform')
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
def train_and_evaluate_model(model, X_train, y_train, X_test, y_test, model_name="Modelo"):
    """
    Entrenar y evaluar modelo
    """
    print(f"Entrenando {model_name}")
    
    # Callbacks para monitorear el entrenamiento
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', 
        factor=0.2, 
        patience=10, 
        min_lr=0.0001,
        verbose=1
    )
    
    # Entrenar modelo
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=100,
        batch_size=32,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    
    # Evaluar modelo
    print(f"\nEvluación {model_name}")
    
    # Predicciones
    y_pred_prob = model.predict(X_test, verbose=0)
    y_pred = (y_pred_prob > 0.5).astype(int).flatten()
    
    # Estadísticas de probabilidades
    print(f"Estadísticas de probabilidades:")
    print(f"  Min: {y_pred_prob.min():.6f}")
    print(f"  Max: {y_pred_prob.max():.6f}")
    print(f"  Mean: {y_pred_prob.mean():.6f}")
    print(f"  Std: {y_pred_prob.std():.6f}")
    print(f"  Mediana: {np.median(y_pred_prob):.6f}")
    
    # Distribución de predicciones
    print(f"\nDistribución de predicciones:")
    unique, counts = np.unique(y_pred, return_counts=True)
    for val, count in zip(unique, counts):
        label = "exitoso" if val == 1 else "no_exitoso"
        print(f"  {label}: {count}")
    
    # Matriz de confusión
    print(f"\nMatriz de confusión:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    
    # Reporte de clasificación
    print(f"\nReporte de clasificación:")
    print(classification_report(y_test, y_pred, target_names=['no_exitoso', 'exitoso']))
    
    # Verificar pesos del modelo
    print(f"\nAnálisis de pesos:")
    for i, layer in enumerate(model.layers):
        if hasattr(layer, 'get_weights') and layer.get_weights():
            weights = layer.get_weights()[0]
            print(f"  Capa {i}: shape={weights.shape}, rango=[{weights.min():.6f}, {weights.max():.6f}]")
    
    return history, y_pred_prob

# %%
# Cargar datos
df = pd.read_csv("../Datos2011Limipios.csv")
print(f"Datos originales: {df.shape}")
print(f"Distribución original:\n{df['resultado'].value_counts()}")
# Out:
# Datos originales: (494094, 29)
# Distribución original:
# resultado
# no_exitoso    476685
# exitoso        17409
# Name: count, dtype: int64

# %%
def balancear_dataframe_simple(df, columna_resultado):
    exitosos = df[df[columna_resultado] == 'exitoso']
    no_exitosos = df[df[columna_resultado] == 'no_exitoso']
    
    min_count = min(len(exitosos), len(no_exitosos))
    
    exitosos_sample = exitosos.sample(min_count, random_state=42)
    no_exitosos_sample = no_exitosos.sample(min_count, random_state=42)
    
    return pd.concat([exitosos_sample, no_exitosos_sample]).sample(frac=1, random_state=42).reset_index(drop=True)

df_balanced = balancear_dataframe_simple(df, 'resultado')
print(f"Datos balanceados: {df_balanced.shape}")
print(f"Distribución balanceada:\n{df_balanced['resultado'].value_counts()}")
# Out:
# Datos balanceados: (34818, 29)
# Distribución balanceada:
# resultado
# exitoso       17409
# no_exitoso    17409
# Name: count, dtype: int64

# %%
categorical_columns = ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 
                       'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
existing_categorical = [col for col in categorical_columns if col in df_balanced.columns]
print(f"Columnas categóricas disponibles: {existing_categorical}")
# Out:
# Columnas categóricas disponibles: ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
df_processed = df_balanced.copy()

# %%
encoders = {}
for col in existing_categorical:
    print(f"Procesando {col}...")
    # Llenar valores nulos
    df_processed[col] = df_processed[col].fillna('unknown')
    
    # Codificar con LabelEncoder
    le = LabelEncoder()
    df_processed[col] = le.fit_transform(df_processed[col].astype(str))
    encoders[col] = le
    
    print(f"  {col}: {len(le.classes_)} clases únicas")
# Out:
# Procesando cole_depto_ubicacion...
#   cole_depto_ubicacion: 34 clases únicas
# Procesando cole_jornada...
#   cole_jornada: 6 clases únicas
# Procesando cole_naturaleza...
#   cole_naturaleza: 2 clases únicas
# Procesando fami_educacionmadre...
#   fami_educacionmadre: 11 clases únicas
# Procesando fami_educacionpadre...
#   fami_educacionpadre: 11 clases únicas
# Procesando fami_estratovivienda...
#   fami_estratovivienda: 6 clases únicas

# %%
feature_columns = existing_categorical
X = df_processed[feature_columns].copy()
y = df_processed['resultado'].map({'no_exitoso': 0, 'exitoso': 1})

print(f"\nFeatures finales: {X.shape}")
print(f"Columnas: {list(X.columns)}")
# Out:
# Features finales: (34818, 6)
# Columnas: ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
scaler = StandardScaler()
X_scaled = pd.DataFrame(
    scaler.fit_transform(X), 
    columns=X.columns, 
    index=X.index
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print(f"\nConjuntos de entrenamiento y prueba:")
print(f"  Train: {X_train.shape}, distribución: {np.bincount(y_train)}")
print(f"  Test: {X_test.shape}, distribución: {np.bincount(y_test)}")
# Out:
# Conjuntos de entrenamiento y prueba:
#   Train: (27854, 6), distribución: [13927 13927]
#   Test: (6964, 6), distribución: [3482 3482]

# %%
improved_model = create_improved_model(X_train.shape[1])
improved_history, improved_probs = train_and_evaluate_model(
    improved_model, X_train, y_train, X_test, y_test, "Mejorado"
)
    
# Guardar el mejor modelo
best_model = improved_model
best_probs = improved_probs
# Out:
# c:\Users\sofia\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Entrenando Baseline
# Epoch 1/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8006 - loss: 0.4375 - val_accuracy: 0.8518 - val_loss: 0.3602 - learning_rate: 0.0100
# Epoch 2/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8521 - loss: 0.3575 - val_accuracy: 0.8532 - val_loss: 0.3605 - learning_rate: 0.0100
# Epoch 3/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8492 - loss: 0.3644 - val_accuracy: 0.8548 - val_loss: 0.3612 - learning_rate: 0.0100
# Epoch 4/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8504 - loss: 0.3612 - val_accuracy: 0.8545 - val_loss: 0.3603 - learning_rate: 0.0100
# Epoch 5/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8517 - loss: 0.3624 - val_accuracy: 0.8532 - val_loss: 0.3601 - learning_rate: 0.0100
# Epoch 6/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8505 - loss: 0.3608 - val_accuracy: 0.8535 - val_loss: 0.3610 - learning_rate: 0.0100
# Epoch 7/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8478 - loss: 0.3650 - val_accuracy: 0.8517 - val_loss: 0.3609 - learning_rate: 0.0100
# Epoch 8/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8495 - loss: 0.3636 - val_accuracy: 0.8527 - val_loss: 0.3600 - learning_rate: 0.0100
# Epoch 9/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8505 - loss: 0.3652 - val_accuracy: 0.8509 - val_loss: 0.3619 - learning_rate: 0.0100
# Epoch 10/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8505 - loss: 0.3608 - val_accuracy: 0.8538 - val_loss: 0.3606 - learning_rate: 0.0100
# Epoch 11/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8453 - loss: 0.3724 - val_accuracy: 0.8544 - val_loss: 0.3606 - learning_rate: 0.0100
# Epoch 12/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8491 - loss: 0.3647 - val_accuracy: 0.8524 - val_loss: 0.3613 - learning_rate: 0.0100
# Epoch 13/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8482 - loss: 0.3660 - val_accuracy: 0.8517 - val_loss: 0.3606 - learning_rate: 0.0100
# Epoch 14/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8518 - loss: 0.3602 - val_accuracy: 0.8524 - val_loss: 0.3618 - learning_rate: 0.0100
# Epoch 15/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8489 - loss: 0.3649 - val_accuracy: 0.8538 - val_loss: 0.3616 - learning_rate: 0.0100
# Epoch 16/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8488 - loss: 0.3636 - val_accuracy: 0.8518 - val_loss: 0.3604 - learning_rate: 0.0100
# Epoch 17/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8484 - loss: 0.3620 - val_accuracy: 0.8522 - val_loss: 0.3610 - learning_rate: 0.0100
# Epoch 18/100
# 856/871 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8480 - loss: 0.3670
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8481 - loss: 0.3669 - val_accuracy: 0.8527 - val_loss: 0.3607 - learning_rate: 0.0100
# Epoch 19/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8534 - loss: 0.3534 - val_accuracy: 0.8528 - val_loss: 0.3603 - learning_rate: 0.0020
# Epoch 20/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8512 - loss: 0.3602 - val_accuracy: 0.8525 - val_loss: 0.3603 - learning_rate: 0.0020
# Epoch 21/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8531 - loss: 0.3559 - val_accuracy: 0.8534 - val_loss: 0.3602 - learning_rate: 0.0020
# Epoch 22/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8513 - loss: 0.3603 - val_accuracy: 0.8532 - val_loss: 0.3602 - learning_rate: 0.0020
# Epoch 23/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8508 - loss: 0.3610 - val_accuracy: 0.8530 - val_loss: 0.3601 - learning_rate: 0.0020
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 8.
#
# Evluación Baseline
# Estadísticas de probabilidades:
#   Min: 0.018583
#   Max: 0.991715
#   Mean: 0.494578
#   Std: 0.367861
#   Mediana: 0.437388
#
# Distribución de predicciones:
#   no_exitoso: 3578
#   exitoso: 3386
#
# Matriz de confusión:
# [[3017  465]
#  [ 561 2921]]
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#   no_exitoso       0.84      0.87      0.85      3482
#      exitoso       0.86      0.84      0.85      3482
#
#     accuracy                           0.85      6964
#    macro avg       0.85      0.85      0.85      6964
# weighted avg       0.85      0.85      0.85      6964
#
#
# Análisis de pesos:
#   Capa 0: shape=(6, 1), rango=[-0.554505, 1.679248]
# Entrenando Mejorado
# Epoch 1/100
# c:\Users\sofia\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8235 - loss: 0.4184 - val_accuracy: 0.8557 - val_loss: 0.3551 - learning_rate: 0.0010
# Epoch 2/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8487 - loss: 0.3733 - val_accuracy: 0.8557 - val_loss: 0.3521 - learning_rate: 0.0010
# Epoch 3/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8507 - loss: 0.3685 - val_accuracy: 0.8554 - val_loss: 0.3531 - learning_rate: 0.0010
# Epoch 4/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8509 - loss: 0.3666 - val_accuracy: 0.8567 - val_loss: 0.3503 - learning_rate: 0.0010
# Epoch 5/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8540 - loss: 0.3608 - val_accuracy: 0.8563 - val_loss: 0.3494 - learning_rate: 0.0010
# Epoch 6/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8541 - loss: 0.3581 - val_accuracy: 0.8555 - val_loss: 0.3487 - learning_rate: 0.0010
# Epoch 7/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8536 - loss: 0.3593 - val_accuracy: 0.8564 - val_loss: 0.3478 - learning_rate: 0.0010
# Epoch 8/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8579 - loss: 0.3513 - val_accuracy: 0.8560 - val_loss: 0.3474 - learning_rate: 0.0010
# Epoch 9/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8557 - loss: 0.3527 - val_accuracy: 0.8561 - val_loss: 0.3474 - learning_rate: 0.0010
# Epoch 10/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8533 - loss: 0.3562 - val_accuracy: 0.8564 - val_loss: 0.3493 - learning_rate: 0.0010
# Epoch 11/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8546 - loss: 0.3572 - val_accuracy: 0.8543 - val_loss: 0.3480 - learning_rate: 0.0010
# Epoch 12/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8533 - loss: 0.3522 - val_accuracy: 0.8555 - val_loss: 0.3494 - learning_rate: 0.0010
# Epoch 13/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8551 - loss: 0.3555 - val_accuracy: 0.8555 - val_loss: 0.3464 - learning_rate: 0.0010
# Epoch 14/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8578 - loss: 0.3508 - val_accuracy: 0.8555 - val_loss: 0.3472 - learning_rate: 0.0010
# Epoch 15/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8579 - loss: 0.3523 - val_accuracy: 0.8560 - val_loss: 0.3465 - learning_rate: 0.0010
# Epoch 16/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8554 - loss: 0.3512 - val_accuracy: 0.8540 - val_loss: 0.3468 - learning_rate: 0.0010
# Epoch 17/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8551 - loss: 0.3547 - val_accuracy: 0.8544 - val_loss: 0.3457 - learning_rate: 0.0010
# Epoch 18/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8552 - loss: 0.3559 - val_accuracy: 0.8544 - val_loss: 0.3459 - learning_rate: 0.0010
# Epoch 19/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8527 - loss: 0.3587 - val_accuracy: 0.8563 - val_loss: 0.3472 - learning_rate: 0.0010
# Epoch 20/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8537 - loss: 0.3587 - val_accuracy: 0.8540 - val_loss: 0.3468 - learning_rate: 0.0010
# Epoch 21/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8575 - loss: 0.3523 - val_accuracy: 0.8543 - val_loss: 0.3461 - learning_rate: 0.0010
# Epoch 22/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8549 - loss: 0.3514 - val_accuracy: 0.8548 - val_loss: 0.3453 - learning_rate: 0.0010
# Epoch 23/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8553 - loss: 0.3527 - val_accuracy: 0.8554 - val_loss: 0.3453 - learning_rate: 0.0010
# Epoch 24/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8570 - loss: 0.3500 - val_accuracy: 0.8551 - val_loss: 0.3457 - learning_rate: 0.0010
# Epoch 25/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8544 - loss: 0.3509 - val_accuracy: 0.8532 - val_loss: 0.3472 - learning_rate: 0.0010
# Epoch 26/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8587 - loss: 0.3435 - val_accuracy: 0.8551 - val_loss: 0.3451 - learning_rate: 0.0010
# Epoch 27/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8597 - loss: 0.3450 - val_accuracy: 0.8540 - val_loss: 0.3466 - learning_rate: 0.0010
# Epoch 28/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8579 - loss: 0.3474 - val_accuracy: 0.8555 - val_loss: 0.3449 - learning_rate: 0.0010
# Epoch 29/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8552 - loss: 0.3515 - val_accuracy: 0.8553 - val_loss: 0.3458 - learning_rate: 0.0010
# Epoch 30/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8549 - loss: 0.3505 - val_accuracy: 0.8564 - val_loss: 0.3475 - learning_rate: 0.0010
# Epoch 31/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8549 - loss: 0.3517 - val_accuracy: 0.8570 - val_loss: 0.3442 - learning_rate: 0.0010
# Epoch 32/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8571 - loss: 0.3447 - val_accuracy: 0.8560 - val_loss: 0.3446 - learning_rate: 0.0010
# Epoch 33/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8581 - loss: 0.3486 - val_accuracy: 0.8553 - val_loss: 0.3478 - learning_rate: 0.0010
# Epoch 34/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8552 - loss: 0.3529 - val_accuracy: 0.8563 - val_loss: 0.3437 - learning_rate: 0.0010
# Epoch 35/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8594 - loss: 0.3485 - val_accuracy: 0.8560 - val_loss: 0.3443 - learning_rate: 0.0010
# Epoch 36/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8589 - loss: 0.3452 - val_accuracy: 0.8560 - val_loss: 0.3455 - learning_rate: 0.0010
# Epoch 37/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8583 - loss: 0.3489 - val_accuracy: 0.8563 - val_loss: 0.3452 - learning_rate: 0.0010
# Epoch 38/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8561 - loss: 0.3543 - val_accuracy: 0.8560 - val_loss: 0.3433 - learning_rate: 0.0010
# Epoch 39/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8548 - loss: 0.3537 - val_accuracy: 0.8577 - val_loss: 0.3439 - learning_rate: 0.0010
# Epoch 40/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8608 - loss: 0.3399 - val_accuracy: 0.8543 - val_loss: 0.3442 - learning_rate: 0.0010
# Epoch 41/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8534 - loss: 0.3530 - val_accuracy: 0.8565 - val_loss: 0.3441 - learning_rate: 0.0010
# Epoch 42/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8539 - loss: 0.3559 - val_accuracy: 0.8567 - val_loss: 0.3448 - learning_rate: 0.0010
# Epoch 43/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8563 - loss: 0.3481 - val_accuracy: 0.8576 - val_loss: 0.3460 - learning_rate: 0.0010
# Epoch 44/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8584 - loss: 0.3492 - val_accuracy: 0.8551 - val_loss: 0.3435 - learning_rate: 0.0010
# Epoch 45/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8586 - loss: 0.3467 - val_accuracy: 0.8561 - val_loss: 0.3437 - learning_rate: 0.0010
# Epoch 46/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8518 - loss: 0.3535 - val_accuracy: 0.8563 - val_loss: 0.3439 - learning_rate: 0.0010
# Epoch 47/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8595 - loss: 0.3434 - val_accuracy: 0.8555 - val_loss: 0.3432 - learning_rate: 0.0010
# Epoch 48/100
# 853/871 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8540 - loss: 0.3517
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8540 - loss: 0.3517 - val_accuracy: 0.8561 - val_loss: 0.3433 - learning_rate: 0.0010
# Epoch 49/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8579 - loss: 0.3477 - val_accuracy: 0.8558 - val_loss: 0.3429 - learning_rate: 2.0000e-04
# Epoch 50/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8580 - loss: 0.3462 - val_accuracy: 0.8557 - val_loss: 0.3428 - learning_rate: 2.0000e-04
# Epoch 51/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8564 - loss: 0.3517 - val_accuracy: 0.8545 - val_loss: 0.3427 - learning_rate: 2.0000e-04
# Epoch 52/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8563 - loss: 0.3520 - val_accuracy: 0.8547 - val_loss: 0.3429 - learning_rate: 2.0000e-04
# Epoch 53/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8585 - loss: 0.3500 - val_accuracy: 0.8548 - val_loss: 0.3429 - learning_rate: 2.0000e-04
# Epoch 54/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8555 - loss: 0.3486 - val_accuracy: 0.8554 - val_loss: 0.3428 - learning_rate: 2.0000e-04
# Epoch 55/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8567 - loss: 0.3474 - val_accuracy: 0.8548 - val_loss: 0.3430 - learning_rate: 2.0000e-04
# Epoch 56/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8564 - loss: 0.3460 - val_accuracy: 0.8545 - val_loss: 0.3429 - learning_rate: 2.0000e-04
# Epoch 57/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8580 - loss: 0.3490 - val_accuracy: 0.8545 - val_loss: 0.3430 - learning_rate: 2.0000e-04
# Epoch 58/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8589 - loss: 0.3480 - val_accuracy: 0.8543 - val_loss: 0.3430 - learning_rate: 2.0000e-04
# Epoch 59/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8610 - loss: 0.3454 - val_accuracy: 0.8550 - val_loss: 0.3425 - learning_rate: 2.0000e-04
# Epoch 60/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8550 - loss: 0.3503 - val_accuracy: 0.8561 - val_loss: 0.3426 - learning_rate: 2.0000e-04
# Epoch 61/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8569 - loss: 0.3412 - val_accuracy: 0.8550 - val_loss: 0.3428 - learning_rate: 2.0000e-04
# Epoch 62/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8594 - loss: 0.3458 - val_accuracy: 0.8553 - val_loss: 0.3425 - learning_rate: 2.0000e-04
# Epoch 63/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8575 - loss: 0.3483 - val_accuracy: 0.8551 - val_loss: 0.3427 - learning_rate: 2.0000e-04
# Epoch 64/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8588 - loss: 0.3462 - val_accuracy: 0.8548 - val_loss: 0.3425 - learning_rate: 2.0000e-04
# Epoch 65/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8553 - loss: 0.3484 - val_accuracy: 0.8554 - val_loss: 0.3424 - learning_rate: 2.0000e-04
# Epoch 66/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8561 - loss: 0.3468 - val_accuracy: 0.8555 - val_loss: 0.3426 - learning_rate: 2.0000e-04
# Epoch 67/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8547 - loss: 0.3505 - val_accuracy: 0.8553 - val_loss: 0.3424 - learning_rate: 2.0000e-04
# Epoch 68/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8576 - loss: 0.3460 - val_accuracy: 0.8555 - val_loss: 0.3426 - learning_rate: 2.0000e-04
# Epoch 69/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8557 - loss: 0.3484 - val_accuracy: 0.8553 - val_loss: 0.3427 - learning_rate: 2.0000e-04
# Epoch 70/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8573 - loss: 0.3453 - val_accuracy: 0.8561 - val_loss: 0.3428 - learning_rate: 2.0000e-04
# Epoch 71/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8572 - loss: 0.3452 - val_accuracy: 0.8561 - val_loss: 0.3427 - learning_rate: 2.0000e-04
# Epoch 72/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8576 - loss: 0.3441 - val_accuracy: 0.8565 - val_loss: 0.3426 - learning_rate: 2.0000e-04
# Epoch 73/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8573 - loss: 0.3468 - val_accuracy: 0.8564 - val_loss: 0.3428 - learning_rate: 2.0000e-04
# Epoch 74/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8579 - loss: 0.3504 - val_accuracy: 0.8557 - val_loss: 0.3425 - learning_rate: 2.0000e-04
# Epoch 75/100
# 861/871 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8566 - loss: 0.3467
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0001.
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8567 - loss: 0.3467 - val_accuracy: 0.8560 - val_loss: 0.3426 - learning_rate: 2.0000e-04
# Epoch 76/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8542 - loss: 0.3526 - val_accuracy: 0.8563 - val_loss: 0.3423 - learning_rate: 1.0000e-04
# Epoch 77/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8599 - loss: 0.3414 - val_accuracy: 0.8561 - val_loss: 0.3425 - learning_rate: 1.0000e-04
# Epoch 78/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8568 - loss: 0.3433 - val_accuracy: 0.8563 - val_loss: 0.3425 - learning_rate: 1.0000e-04
# Epoch 79/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8573 - loss: 0.3450 - val_accuracy: 0.8563 - val_loss: 0.3425 - learning_rate: 1.0000e-04
# Epoch 80/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8618 - loss: 0.3419 - val_accuracy: 0.8560 - val_loss: 0.3427 - learning_rate: 1.0000e-04
# Epoch 81/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8608 - loss: 0.3429 - val_accuracy: 0.8555 - val_loss: 0.3426 - learning_rate: 1.0000e-04
# Epoch 82/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8552 - loss: 0.3480 - val_accuracy: 0.8560 - val_loss: 0.3425 - learning_rate: 1.0000e-04
# Epoch 83/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8609 - loss: 0.3419 - val_accuracy: 0.8560 - val_loss: 0.3425 - learning_rate: 1.0000e-04
# Epoch 84/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8603 - loss: 0.3366 - val_accuracy: 0.8560 - val_loss: 0.3426 - learning_rate: 1.0000e-04
# Epoch 85/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8575 - loss: 0.3501 - val_accuracy: 0.8560 - val_loss: 0.3425 - learning_rate: 1.0000e-04
# Epoch 86/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8562 - loss: 0.3435 - val_accuracy: 0.8558 - val_loss: 0.3426 - learning_rate: 1.0000e-04
# Epoch 87/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8600 - loss: 0.3371 - val_accuracy: 0.8560 - val_loss: 0.3426 - learning_rate: 1.0000e-04
# Epoch 88/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8587 - loss: 0.3449 - val_accuracy: 0.8564 - val_loss: 0.3425 - learning_rate: 1.0000e-04
# Epoch 89/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8595 - loss: 0.3432 - val_accuracy: 0.8561 - val_loss: 0.3425 - learning_rate: 1.0000e-04
# Epoch 90/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8580 - loss: 0.3417 - val_accuracy: 0.8558 - val_loss: 0.3426 - learning_rate: 1.0000e-04
# Epoch 91/100
# 871/871 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8566 - loss: 0.3480 - val_accuracy: 0.8563 - val_loss: 0.3424 - learning_rate: 1.0000e-04
# Epoch 91: early stopping
# Restoring model weights from the end of the best epoch: 76.
#
# Evluación Mejorado
# Estadísticas de probabilidades:
#   Min: 0.013540
#   Max: 0.993822
#   Mean: 0.499780
#   Std: 0.380725
#   Mediana: 0.472099
#
# Distribución de predicciones:
#   no_exitoso: 3561
#   exitoso: 3403
#
# Matriz de confusión:
# [[3021  461]
#  [ 540 2942]]
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#   no_exitoso       0.85      0.87      0.86      3482
#      exitoso       0.86      0.84      0.85      3482
#
#     accuracy                           0.86      6964
#    macro avg       0.86      0.86      0.86      6964
# weighted avg       0.86      0.86      0.86      6964
#
#
# Análisis de pesos:
#   Capa 0: shape=(6, 64), rango=[-0.705883, 1.006931]
#   Capa 2: shape=(64, 32), rango=[-1.699380, 0.519333]
#   Capa 4: shape=(32, 1), rango=[-0.575024, 0.846417]

# %%
best_model.save('modelo_final.keras')
# Guardar información de preprocesamiento
import pickle
preprocessing_info = {
    'feature_columns': feature_columns,
    'encoders': encoders,
    'scaler': scaler,
    'categorical_columns': existing_categorical
    }
    
with open('preprocessing_info.pkl', 'wb') as f:
    pickle.dump(preprocessing_info, f)

# %%
def test_predictions_on_sample(model_path, preprocessing_path, sample_data):
    """
    Probar predicciones en datos de muestra
    """
    model = tf.keras.models.load_model(model_path)
    
    with open(preprocessing_path, 'rb') as f:
        prep_info = pickle.load(f)
    
    # Procesar datos
    sample_processed = sample_data.copy()
    
    for col in prep_info['categorical_columns']:
        if col in sample_processed.columns:
            sample_processed[col] = sample_processed[col].fillna('unknown')
            le = prep_info['encoders'][col]
            # Manejar valores no vistos
            sample_processed[col] = sample_processed[col].astype(str).apply(
                lambda x: x if x in le.classes_ else le.classes_[0]
            )
            sample_processed[col] = le.transform(sample_processed[col])
    
    # Normalizar
    sample_scaled = prep_info['scaler'].transform(sample_processed[prep_info['feature_columns']])
    
    # Predecir
    probs = model.predict(sample_scaled, verbose=0)
    preds = (probs > 0.5).astype(int)
    
    return probs, preds

# %%
sample_data = df_balanced[existing_categorical].iloc[:-1]
    
try:
    probs, preds = test_predictions_on_sample(
        'modelo_final.keras',
        'preprocessing_info.pkl',
        sample_data
        )
        
    print("Predicciones en muestra:")
    for i, (prob, pred) in enumerate(zip(probs.flatten(), preds.flatten())):
        real = df_balanced['resultado'].iloc[i]
        pred_label = 'exitoso' if pred == 1 else 'no_exitoso'
        print(f"  Ejemplo {i+1}: {pred_label} (prob: {prob:.4f}), Real: {real}")
            
except Exception as e:
    print(f"Error al probar predicciones: {e}")
# Out:
# Predicciones en muestra:
#   Ejemplo 1: no_exitoso (prob: 0.2332), Real: exitoso
#   Ejemplo 2: no_exitoso (prob: 0.1587), Real: no_exitoso
#   Ejemplo 3: exitoso (prob: 0.7596), Real: no_exitoso
#   Ejemplo 4: no_exitoso (prob: 0.4434), Real: no_exitoso
#   Ejemplo 5: exitoso (prob: 0.9924), Real: exitoso
#   Ejemplo 6: exitoso (prob: 0.9642), Real: exitoso
#   Ejemplo 7: no_exitoso (prob: 0.1587), Real: no_exitoso
#   Ejemplo 8: exitoso (prob: 0.6810), Real: exitoso
#   Ejemplo 9: exitoso (prob: 0.9872), Real: exitoso
#   Ejemplo 10: exitoso (prob: 0.9935), Real: exitoso
#   Ejemplo 11: no_exitoso (prob: 0.2009), Real: no_exitoso
#   Ejemplo 12: no_exitoso (prob: 0.1015), Real: no_exitoso
#   Ejemplo 13: no_exitoso (prob: 0.1139), Real: no_exitoso
#   Ejemplo 14: no_exitoso (prob: 0.0220), Real: no_exitoso
#   Ejemplo 15: no_exitoso (prob: 0.1638), Real: no_exitoso
#   Ejemplo 16: no_exitoso (prob: 0.0295), Real: no_exitoso
#   Ejemplo 17: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 18: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 19: exitoso (prob: 0.7469), Real: no_exitoso
#   Ejemplo 20: exitoso (prob: 0.9568), Real: exitoso
#   Ejemplo 21: exitoso (prob: 0.8721), Real: exitoso
#   Ejemplo 22: exitoso (prob: 0.9703), Real: exitoso
#   Ejemplo 23: exitoso (prob: 0.7444), Real: exitoso
#   Ejemplo 24: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 25: no_exitoso (prob: 0.0886), Real: exitoso
#   Ejemplo 26: no_exitoso (prob: 0.1403), Real: no_exitoso
#   Ejemplo 27: no_exitoso (prob: 0.0766), Real: no_exitoso
#   Ejemplo 28: no_exitoso (prob: 0.3763), Real: exitoso
#   Ejemplo 29: no_exitoso (prob: 0.0304), Real: exitoso
#   Ejemplo 30: no_exitoso (prob: 0.1430), Real: no_exitoso
#   Ejemplo 31: no_exitoso (prob: 0.4051), Real: exitoso
#   Ejemplo 32: no_exitoso (prob: 0.1153), Real: no_exitoso
#   Ejemplo 33: no_exitoso (prob: 0.0889), Real: no_exitoso
#   Ejemplo 34: no_exitoso (prob: 0.1998), Real: no_exitoso
#   Ejemplo 35: exitoso (prob: 0.8595), Real: exitoso
#   Ejemplo 36: exitoso (prob: 0.9822), Real: exitoso
#   Ejemplo 37: no_exitoso (prob: 0.0744), Real: no_exitoso
#   Ejemplo 38: no_exitoso (prob: 0.0297), Real: no_exitoso
#   Ejemplo 39: no_exitoso (prob: 0.1779), Real: no_exitoso
#   Ejemplo 40: no_exitoso (prob: 0.1952), Real: no_exitoso
#   Ejemplo 41: no_exitoso (prob: 0.0339), Real: no_exitoso
#   Ejemplo 42: no_exitoso (prob: 0.0308), Real: exitoso
#   Ejemplo 43: no_exitoso (prob: 0.0415), Real: no_exitoso
#   Ejemplo 44: exitoso (prob: 0.9525), Real: exitoso
#   Ejemplo 45: no_exitoso (prob: 0.2004), Real: no_exitoso
#   Ejemplo 46: no_exitoso (prob: 0.0902), Real: no_exitoso
#   Ejemplo 47: no_exitoso (prob: 0.0167), Real: no_exitoso
#   Ejemplo 48: no_exitoso (prob: 0.3146), Real: no_exitoso
#   Ejemplo 49: exitoso (prob: 0.9745), Real: exitoso
#   Ejemplo 50: exitoso (prob: 0.5154), Real: no_exitoso
#   Ejemplo 51: exitoso (prob: 0.9926), Real: exitoso
#   Ejemplo 52: exitoso (prob: 0.7463), Real: exitoso
#   Ejemplo 53: exitoso (prob: 0.8996), Real: exitoso
#   Ejemplo 54: no_exitoso (prob: 0.0722), Real: no_exitoso
#   Ejemplo 55: no_exitoso (prob: 0.0282), Real: no_exitoso
#   Ejemplo 56: no_exitoso (prob: 0.3432), Real: no_exitoso
#   Ejemplo 57: no_exitoso (prob: 0.0943), Real: no_exitoso
#   Ejemplo 58: exitoso (prob: 0.9931), Real: exitoso
#   Ejemplo 59: no_exitoso (prob: 0.3507), Real: exitoso
#   Ejemplo 60: no_exitoso (prob: 0.0558), Real: no_exitoso
#   Ejemplo 61: no_exitoso (prob: 0.0461), Real: no_exitoso
#   Ejemplo 62: no_exitoso (prob: 0.0207), Real: no_exitoso
#   Ejemplo 63: exitoso (prob: 0.8954), Real: no_exitoso
#   Ejemplo 64: no_exitoso (prob: 0.3708), Real: no_exitoso
#   Ejemplo 65: no_exitoso (prob: 0.0229), Real: no_exitoso
#   Ejemplo 66: no_exitoso (prob: 0.1505), Real: exitoso
#   Ejemplo 67: no_exitoso (prob: 0.0469), Real: no_exitoso
#   Ejemplo 68: no_exitoso (prob: 0.0722), Real: exitoso
#   Ejemplo 69: exitoso (prob: 0.9839), Real: exitoso
#   Ejemplo 70: exitoso (prob: 0.9610), Real: exitoso
#   Ejemplo 71: no_exitoso (prob: 0.3318), Real: no_exitoso
#   Ejemplo 72: no_exitoso (prob: 0.0167), Real: no_exitoso
#   Ejemplo 73: exitoso (prob: 0.9854), Real: exitoso
#   Ejemplo 74: exitoso (prob: 0.8527), Real: exitoso
#   Ejemplo 75: exitoso (prob: 0.7382), Real: exitoso
#   Ejemplo 76: no_exitoso (prob: 0.0640), Real: no_exitoso
#   Ejemplo 77: exitoso (prob: 0.7194), Real: exitoso
#   Ejemplo 78: no_exitoso (prob: 0.2375), Real: no_exitoso
#   Ejemplo 79: no_exitoso (prob: 0.0375), Real: no_exitoso
#   Ejemplo 80: exitoso (prob: 0.9395), Real: exitoso
#   Ejemplo 81: exitoso (prob: 0.6577), Real: exitoso
#   Ejemplo 82: exitoso (prob: 0.5347), Real: no_exitoso
#   Ejemplo 83: no_exitoso (prob: 0.2748), Real: no_exitoso
#   Ejemplo 84: exitoso (prob: 0.9891), Real: exitoso
#   Ejemplo 85: exitoso (prob: 0.7473), Real: exitoso
#   Ejemplo 86: no_exitoso (prob: 0.0682), Real: no_exitoso
#   Ejemplo 87: exitoso (prob: 0.9693), Real: exitoso
#   Ejemplo 88: exitoso (prob: 0.8905), Real: exitoso
#   Ejemplo 89: no_exitoso (prob: 0.3705), Real: exitoso
#   Ejemplo 90: exitoso (prob: 0.8433), Real: exitoso
#   Ejemplo 91: no_exitoso (prob: 0.3540), Real: no_exitoso
#   Ejemplo 92: exitoso (prob: 0.9934), Real: exitoso
#   Ejemplo 93: no_exitoso (prob: 0.0249), Real: no_exitoso
#   Ejemplo 94: no_exitoso (prob: 0.0728), Real: no_exitoso
#   Ejemplo 95: exitoso (prob: 0.9662), Real: exitoso
#   Ejemplo 96: no_exitoso (prob: 0.0321), Real: no_exitoso
#   Ejemplo 97: no_exitoso (prob: 0.3350), Real: no_exitoso
#   Ejemplo 98: exitoso (prob: 0.9576), Real: exitoso
#   Ejemplo 99: no_exitoso (prob: 0.0569), Real: no_exitoso
#   Ejemplo 100: exitoso (prob: 0.9525), Real: exitoso
#   Ejemplo 101: no_exitoso (prob: 0.1461), Real: no_exitoso
#   Ejemplo 102: no_exitoso (prob: 0.1602), Real: no_exitoso
#   Ejemplo 103: no_exitoso (prob: 0.2757), Real: no_exitoso
#   Ejemplo 104: no_exitoso (prob: 0.1447), Real: no_exitoso
#   Ejemplo 105: exitoso (prob: 0.5934), Real: no_exitoso
#   Ejemplo 106: no_exitoso (prob: 0.1604), Real: no_exitoso
#   Ejemplo 107: exitoso (prob: 0.9915), Real: exitoso
#   Ejemplo 108: exitoso (prob: 0.8516), Real: exitoso
#   Ejemplo 109: exitoso (prob: 0.5713), Real: no_exitoso
#   Ejemplo 110: no_exitoso (prob: 0.0155), Real: no_exitoso
#   Ejemplo 111: exitoso (prob: 0.9342), Real: exitoso
#   Ejemplo 112: no_exitoso (prob: 0.0621), Real: no_exitoso
#   Ejemplo 113: exitoso (prob: 0.6577), Real: exitoso
#   Ejemplo 114: exitoso (prob: 0.9473), Real: exitoso
#   Ejemplo 115: exitoso (prob: 0.7491), Real: exitoso
#   Ejemplo 116: no_exitoso (prob: 0.0510), Real: no_exitoso
#   Ejemplo 117: no_exitoso (prob: 0.2101), Real: exitoso
#   Ejemplo 118: exitoso (prob: 0.8912), Real: exitoso
#   Ejemplo 119: no_exitoso (prob: 0.3090), Real: no_exitoso
#   Ejemplo 120: exitoso (prob: 0.5698), Real: exitoso
#   Ejemplo 121: exitoso (prob: 0.9575), Real: exitoso
#   Ejemplo 122: no_exitoso (prob: 0.1391), Real: no_exitoso
#   Ejemplo 123: exitoso (prob: 0.6618), Real: no_exitoso
#   Ejemplo 124: exitoso (prob: 0.8679), Real: no_exitoso
#   Ejemplo 125: no_exitoso (prob: 0.0152), Real: no_exitoso
#   Ejemplo 126: exitoso (prob: 0.9118), Real: no_exitoso
#   Ejemplo 127: exitoso (prob: 0.5942), Real: no_exitoso
#   Ejemplo 128: exitoso (prob: 0.9922), Real: no_exitoso
#   Ejemplo 129: exitoso (prob: 0.9823), Real: exitoso
#   Ejemplo 130: exitoso (prob: 0.8134), Real: exitoso
#   Ejemplo 131: exitoso (prob: 0.9524), Real: exitoso
#   Ejemplo 132: exitoso (prob: 0.5790), Real: exitoso
#   Ejemplo 133: no_exitoso (prob: 0.0696), Real: no_exitoso
#   Ejemplo 134: exitoso (prob: 0.8225), Real: exitoso
#   Ejemplo 135: no_exitoso (prob: 0.0236), Real: exitoso
#   Ejemplo 136: no_exitoso (prob: 0.1373), Real: no_exitoso
#   Ejemplo 137: no_exitoso (prob: 0.0156), Real: no_exitoso
#   Ejemplo 138: exitoso (prob: 0.7629), Real: no_exitoso
#   Ejemplo 139: no_exitoso (prob: 0.0797), Real: no_exitoso
#   Ejemplo 140: no_exitoso (prob: 0.2172), Real: no_exitoso
#   Ejemplo 141: exitoso (prob: 0.9701), Real: exitoso
#   Ejemplo 142: no_exitoso (prob: 0.0231), Real: no_exitoso
#   Ejemplo 143: exitoso (prob: 0.9869), Real: exitoso
#   Ejemplo 144: no_exitoso (prob: 0.0723), Real: no_exitoso
#   Ejemplo 145: no_exitoso (prob: 0.0152), Real: no_exitoso
#   Ejemplo 146: exitoso (prob: 0.9345), Real: no_exitoso
#   Ejemplo 147: no_exitoso (prob: 0.1491), Real: no_exitoso
#   Ejemplo 148: exitoso (prob: 0.9922), Real: exitoso
#   Ejemplo 149: no_exitoso (prob: 0.0486), Real: no_exitoso
#   Ejemplo 150: no_exitoso (prob: 0.0620), Real: no_exitoso
#   Ejemplo 151: exitoso (prob: 0.9927), Real: exitoso
#   Ejemplo 152: exitoso (prob: 0.9703), Real: exitoso
#   Ejemplo 153: no_exitoso (prob: 0.1116), Real: no_exitoso
#   Ejemplo 154: no_exitoso (prob: 0.0298), Real: no_exitoso
#   Ejemplo 155: exitoso (prob: 0.8403), Real: exitoso
#   Ejemplo 156: exitoso (prob: 0.8971), Real: exitoso
#   Ejemplo 157: no_exitoso (prob: 0.0757), Real: no_exitoso
#   Ejemplo 158: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 159: no_exitoso (prob: 0.2783), Real: no_exitoso
#   Ejemplo 160: no_exitoso (prob: 0.1948), Real: no_exitoso
#   Ejemplo 161: exitoso (prob: 0.6161), Real: exitoso
#   Ejemplo 162: no_exitoso (prob: 0.3920), Real: no_exitoso
#   Ejemplo 163: exitoso (prob: 0.9894), Real: exitoso
#   Ejemplo 164: exitoso (prob: 0.9608), Real: exitoso
#   Ejemplo 165: exitoso (prob: 0.8372), Real: exitoso
#   Ejemplo 166: exitoso (prob: 0.9926), Real: exitoso
#   Ejemplo 167: no_exitoso (prob: 0.0273), Real: no_exitoso
#   Ejemplo 168: no_exitoso (prob: 0.0706), Real: no_exitoso
#   Ejemplo 169: exitoso (prob: 0.9839), Real: exitoso
#   Ejemplo 170: no_exitoso (prob: 0.3065), Real: exitoso
#   Ejemplo 171: exitoso (prob: 0.8372), Real: exitoso
#   Ejemplo 172: no_exitoso (prob: 0.1219), Real: no_exitoso
#   Ejemplo 173: exitoso (prob: 0.7440), Real: exitoso
#   Ejemplo 174: no_exitoso (prob: 0.0152), Real: no_exitoso
#   Ejemplo 175: exitoso (prob: 0.9703), Real: exitoso
#   Ejemplo 176: no_exitoso (prob: 0.0889), Real: no_exitoso
#   Ejemplo 177: no_exitoso (prob: 0.0196), Real: no_exitoso
#   Ejemplo 178: exitoso (prob: 0.7305), Real: exitoso
#   Ejemplo 179: no_exitoso (prob: 0.1603), Real: no_exitoso
#   Ejemplo 180: no_exitoso (prob: 0.2295), Real: no_exitoso
#   Ejemplo 181: exitoso (prob: 0.7323), Real: exitoso
#   Ejemplo 182: no_exitoso (prob: 0.3090), Real: no_exitoso
#   Ejemplo 183: exitoso (prob: 0.7323), Real: exitoso
#   Ejemplo 184: exitoso (prob: 0.6896), Real: exitoso
#   Ejemplo 185: exitoso (prob: 0.9637), Real: exitoso
#   Ejemplo 186: exitoso (prob: 0.9822), Real: exitoso
#   Ejemplo 187: exitoso (prob: 0.9869), Real: exitoso
#   Ejemplo 188: no_exitoso (prob: 0.4205), Real: exitoso
#   Ejemplo 189: exitoso (prob: 0.9867), Real: exitoso
#   Ejemplo 190: no_exitoso (prob: 0.0358), Real: no_exitoso
#   Ejemplo 191: no_exitoso (prob: 0.3528), Real: no_exitoso
#   Ejemplo 192: exitoso (prob: 0.5790), Real: exitoso
#   Ejemplo 193: no_exitoso (prob: 0.1084), Real: no_exitoso
#   Ejemplo 194: exitoso (prob: 0.6655), Real: exitoso
#   Ejemplo 195: exitoso (prob: 0.9588), Real: exitoso
#   Ejemplo 196: no_exitoso (prob: 0.0744), Real: no_exitoso
#   Ejemplo 197: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 198: no_exitoso (prob: 0.0718), Real: no_exitoso
#   Ejemplo 199: no_exitoso (prob: 0.0212), Real: no_exitoso
#   Ejemplo 200: no_exitoso (prob: 0.2278), Real: no_exitoso
#   Ejemplo 201: no_exitoso (prob: 0.2913), Real: no_exitoso
#   Ejemplo 202: exitoso (prob: 0.7067), Real: exitoso
#   Ejemplo 203: no_exitoso (prob: 0.0398), Real: no_exitoso
#   Ejemplo 204: no_exitoso (prob: 0.3846), Real: exitoso
#   Ejemplo 205: no_exitoso (prob: 0.3705), Real: no_exitoso
#   Ejemplo 206: exitoso (prob: 0.9869), Real: exitoso
#   Ejemplo 207: exitoso (prob: 0.9915), Real: exitoso
#   Ejemplo 208: no_exitoso (prob: 0.0744), Real: no_exitoso
#   Ejemplo 209: exitoso (prob: 0.9701), Real: exitoso
#   Ejemplo 210: exitoso (prob: 0.7960), Real: exitoso
#   Ejemplo 211: exitoso (prob: 0.7347), Real: exitoso
#   Ejemplo 212: no_exitoso (prob: 0.1587), Real: no_exitoso
#   Ejemplo 213: no_exitoso (prob: 0.0308), Real: no_exitoso
#   Ejemplo 214: exitoso (prob: 0.7440), Real: exitoso
#   Ejemplo 215: exitoso (prob: 0.9894), Real: exitoso
#   Ejemplo 216: no_exitoso (prob: 0.1203), Real: exitoso
#   Ejemplo 217: exitoso (prob: 0.5401), Real: exitoso
#   Ejemplo 218: no_exitoso (prob: 0.1620), Real: no_exitoso
#   Ejemplo 219: no_exitoso (prob: 0.1376), Real: no_exitoso
#   Ejemplo 220: exitoso (prob: 0.8379), Real: no_exitoso
#   Ejemplo 221: no_exitoso (prob: 0.0192), Real: no_exitoso
#   Ejemplo 222: no_exitoso (prob: 0.0704), Real: no_exitoso
#   Ejemplo 223: no_exitoso (prob: 0.3821), Real: exitoso
#   Ejemplo 224: no_exitoso (prob: 0.3769), Real: no_exitoso
#   Ejemplo 225: no_exitoso (prob: 0.1602), Real: no_exitoso
#   Ejemplo 226: exitoso (prob: 0.9693), Real: exitoso
#   Ejemplo 227: exitoso (prob: 0.6036), Real: exitoso
#   Ejemplo 228: no_exitoso (prob: 0.1139), Real: no_exitoso
#   Ejemplo 229: exitoso (prob: 0.9867), Real: exitoso
#   Ejemplo 230: no_exitoso (prob: 0.0273), Real: no_exitoso
#   Ejemplo 231: no_exitoso (prob: 0.0803), Real: no_exitoso
#   Ejemplo 232: no_exitoso (prob: 0.2051), Real: no_exitoso
#   Ejemplo 233: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 234: exitoso (prob: 0.9698), Real: exitoso
#   Ejemplo 235: no_exitoso (prob: 0.0286), Real: no_exitoso
#   Ejemplo 236: no_exitoso (prob: 0.0429), Real: no_exitoso
#   Ejemplo 237: no_exitoso (prob: 0.0881), Real: no_exitoso
#   Ejemplo 238: exitoso (prob: 0.8408), Real: exitoso
#   Ejemplo 239: no_exitoso (prob: 0.0168), Real: no_exitoso
#   Ejemplo 240: no_exitoso (prob: 0.2940), Real: no_exitoso
#   Ejemplo 241: no_exitoso (prob: 0.3411), Real: exitoso
#   Ejemplo 242: no_exitoso (prob: 0.2463), Real: no_exitoso
#   Ejemplo 243: exitoso (prob: 0.8378), Real: exitoso
#   Ejemplo 244: no_exitoso (prob: 0.0629), Real: no_exitoso
#   Ejemplo 245: no_exitoso (prob: 0.3558), Real: exitoso
#   Ejemplo 246: exitoso (prob: 0.6752), Real: no_exitoso
#   Ejemplo 247: exitoso (prob: 0.9600), Real: exitoso
#   Ejemplo 248: no_exitoso (prob: 0.1289), Real: no_exitoso
#   Ejemplo 249: exitoso (prob: 0.9473), Real: exitoso
#   Ejemplo 250: no_exitoso (prob: 0.1851), Real: no_exitoso
#   Ejemplo 251: exitoso (prob: 0.6668), Real: no_exitoso
#   Ejemplo 252: no_exitoso (prob: 0.0486), Real: no_exitoso
#   Ejemplo 253: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 254: no_exitoso (prob: 0.3159), Real: exitoso
#   Ejemplo 255: no_exitoso (prob: 0.1439), Real: no_exitoso
#   Ejemplo 256: no_exitoso (prob: 0.0237), Real: no_exitoso
#   Ejemplo 257: no_exitoso (prob: 0.0165), Real: no_exitoso
#   Ejemplo 258: no_exitoso (prob: 0.1419), Real: no_exitoso
#   Ejemplo 259: no_exitoso (prob: 0.0641), Real: no_exitoso
#   Ejemplo 260: no_exitoso (prob: 0.0766), Real: no_exitoso
#   Ejemplo 261: exitoso (prob: 0.7415), Real: no_exitoso
#   Ejemplo 262: no_exitoso (prob: 0.0760), Real: no_exitoso
#   Ejemplo 263: no_exitoso (prob: 0.2026), Real: no_exitoso
#   Ejemplo 264: exitoso (prob: 0.9870), Real: exitoso
#   Ejemplo 265: exitoso (prob: 0.9845), Real: exitoso
#   Ejemplo 266: exitoso (prob: 0.9598), Real: exitoso
#   Ejemplo 267: exitoso (prob: 0.8391), Real: exitoso
#   Ejemplo 268: exitoso (prob: 0.8242), Real: exitoso
#   Ejemplo 269: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 270: exitoso (prob: 0.9366), Real: exitoso
#   Ejemplo 271: no_exitoso (prob: 0.1266), Real: no_exitoso
#   Ejemplo 272: exitoso (prob: 0.6156), Real: no_exitoso
#   Ejemplo 273: no_exitoso (prob: 0.1475), Real: no_exitoso
#   Ejemplo 274: exitoso (prob: 0.9849), Real: exitoso
#   Ejemplo 275: no_exitoso (prob: 0.2139), Real: no_exitoso
#   Ejemplo 276: no_exitoso (prob: 0.0574), Real: no_exitoso
#   Ejemplo 277: no_exitoso (prob: 0.0167), Real: no_exitoso
#   Ejemplo 278: no_exitoso (prob: 0.0569), Real: no_exitoso
#   Ejemplo 279: exitoso (prob: 0.7238), Real: exitoso
#   Ejemplo 280: exitoso (prob: 0.7301), Real: exitoso
#   Ejemplo 281: no_exitoso (prob: 0.1670), Real: no_exitoso
#   Ejemplo 282: no_exitoso (prob: 0.0355), Real: no_exitoso
#   Ejemplo 283: exitoso (prob: 0.6708), Real: exitoso
#   Ejemplo 284: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 285: exitoso (prob: 0.9926), Real: exitoso
#   Ejemplo 286: no_exitoso (prob: 0.0215), Real: no_exitoso
#   Ejemplo 287: exitoso (prob: 0.9867), Real: exitoso
#   Ejemplo 288: no_exitoso (prob: 0.0670), Real: no_exitoso
#   Ejemplo 289: exitoso (prob: 0.8954), Real: exitoso
#   Ejemplo 290: no_exitoso (prob: 0.1683), Real: no_exitoso
#   Ejemplo 291: exitoso (prob: 0.5537), Real: exitoso
#   Ejemplo 292: no_exitoso (prob: 0.0932), Real: no_exitoso
#   Ejemplo 293: no_exitoso (prob: 0.0704), Real: no_exitoso
#   Ejemplo 294: exitoso (prob: 0.9714), Real: exitoso
#   Ejemplo 295: exitoso (prob: 0.9788), Real: exitoso
#   Ejemplo 296: exitoso (prob: 0.9683), Real: exitoso
#   Ejemplo 297: exitoso (prob: 0.9601), Real: exitoso
#   Ejemplo 298: no_exitoso (prob: 0.3215), Real: exitoso
#   Ejemplo 299: no_exitoso (prob: 0.0491), Real: exitoso
#   Ejemplo 300: no_exitoso (prob: 0.0221), Real: no_exitoso
#   Ejemplo 301: exitoso (prob: 0.9698), Real: no_exitoso
#   Ejemplo 302: no_exitoso (prob: 0.0167), Real: no_exitoso
#   Ejemplo 303: exitoso (prob: 0.7437), Real: exitoso
#   Ejemplo 304: no_exitoso (prob: 0.0750), Real: no_exitoso
#   Ejemplo 305: exitoso (prob: 0.9935), Real: exitoso
#   Ejemplo 306: exitoso (prob: 0.9423), Real: exitoso
#   Ejemplo 307: exitoso (prob: 0.5777), Real: exitoso
#   Ejemplo 308: exitoso (prob: 0.9572), Real: exitoso
#   Ejemplo 309: exitoso (prob: 0.9821), Real: exitoso
#   Ejemplo 310: exitoso (prob: 0.9253), Real: exitoso
#   Ejemplo 311: no_exitoso (prob: 0.3515), Real: exitoso
#   Ejemplo 312: no_exitoso (prob: 0.2940), Real: no_exitoso
#   Ejemplo 313: exitoso (prob: 0.7461), Real: exitoso
#   Ejemplo 314: exitoso (prob: 0.7440), Real: exitoso
#   Ejemplo 315: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 316: exitoso (prob: 0.5370), Real: no_exitoso
#   Ejemplo 317: no_exitoso (prob: 0.0584), Real: no_exitoso
#   Ejemplo 318: no_exitoso (prob: 0.3434), Real: no_exitoso
#   Ejemplo 319: no_exitoso (prob: 0.0909), Real: no_exitoso
#   Ejemplo 320: no_exitoso (prob: 0.3150), Real: no_exitoso
#   Ejemplo 321: exitoso (prob: 0.8986), Real: exitoso
#   Ejemplo 322: no_exitoso (prob: 0.0181), Real: no_exitoso
#   Ejemplo 323: no_exitoso (prob: 0.1171), Real: no_exitoso
#   Ejemplo 324: exitoso (prob: 0.8931), Real: exitoso
#   Ejemplo 325: no_exitoso (prob: 0.1784), Real: no_exitoso
#   Ejemplo 326: exitoso (prob: 0.9927), Real: exitoso
#   Ejemplo 327: no_exitoso (prob: 0.0537), Real: no_exitoso
#   Ejemplo 328: no_exitoso (prob: 0.0633), Real: no_exitoso
#   Ejemplo 329: exitoso (prob: 0.9693), Real: exitoso
#   Ejemplo 330: exitoso (prob: 0.9463), Real: exitoso
#   Ejemplo 331: no_exitoso (prob: 0.3424), Real: exitoso
#   Ejemplo 332: exitoso (prob: 0.9884), Real: exitoso
#   Ejemplo 333: exitoso (prob: 0.6327), Real: exitoso
#   Ejemplo 334: exitoso (prob: 0.6901), Real: exitoso
#   Ejemplo 335: exitoso (prob: 0.5790), Real: exitoso
#   Ejemplo 336: no_exitoso (prob: 0.3186), Real: no_exitoso
#   Ejemplo 337: no_exitoso (prob: 0.0991), Real: no_exitoso
#   Ejemplo 338: exitoso (prob: 0.9568), Real: exitoso
#   Ejemplo 339: exitoso (prob: 0.8888), Real: exitoso
#   Ejemplo 340: exitoso (prob: 0.9703), Real: exitoso
#   Ejemplo 341: exitoso (prob: 0.9862), Real: exitoso
#   Ejemplo 342: exitoso (prob: 0.6447), Real: no_exitoso
#   Ejemplo 343: exitoso (prob: 0.7434), Real: exitoso
#   Ejemplo 344: exitoso (prob: 0.9530), Real: exitoso
#   Ejemplo 345: exitoso (prob: 0.5925), Real: no_exitoso
#   Ejemplo 346: exitoso (prob: 0.5131), Real: exitoso
#   Ejemplo 347: no_exitoso (prob: 0.0376), Real: exitoso
#   Ejemplo 348: exitoso (prob: 0.9662), Real: exitoso
#   Ejemplo 349: exitoso (prob: 0.7052), Real: exitoso
#   Ejemplo 350: exitoso (prob: 0.9499), Real: exitoso
#   Ejemplo 351: no_exitoso (prob: 0.4643), Real: no_exitoso
#   Ejemplo 352: exitoso (prob: 0.6238), Real: no_exitoso
#   Ejemplo 353: no_exitoso (prob: 0.0895), Real: no_exitoso
#   Ejemplo 354: exitoso (prob: 0.9316), Real: exitoso
#   Ejemplo 355: no_exitoso (prob: 0.3449), Real: no_exitoso
#   Ejemplo 356: exitoso (prob: 0.9463), Real: exitoso
#   Ejemplo 357: exitoso (prob: 0.6136), Real: no_exitoso
#   Ejemplo 358: no_exitoso (prob: 0.2992), Real: no_exitoso
#   Ejemplo 359: no_exitoso (prob: 0.0670), Real: no_exitoso
#   Ejemplo 360: exitoso (prob: 0.9168), Real: exitoso
#   Ejemplo 361: exitoso (prob: 0.9635), Real: no_exitoso
#   Ejemplo 362: exitoso (prob: 0.5993), Real: exitoso
#   Ejemplo 363: exitoso (prob: 0.7379), Real: exitoso
#   Ejemplo 364: no_exitoso (prob: 0.2037), Real: no_exitoso
#   Ejemplo 365: no_exitoso (prob: 0.0175), Real: no_exitoso
#   Ejemplo 366: no_exitoso (prob: 0.3980), Real: no_exitoso
#   Ejemplo 367: no_exitoso (prob: 0.0362), Real: no_exitoso
#   Ejemplo 368: no_exitoso (prob: 0.4189), Real: exitoso
#   Ejemplo 369: exitoso (prob: 0.5277), Real: exitoso
#   Ejemplo 370: no_exitoso (prob: 0.0227), Real: no_exitoso
#   Ejemplo 371: no_exitoso (prob: 0.0533), Real: no_exitoso
#   Ejemplo 372: exitoso (prob: 0.9849), Real: exitoso
#   Ejemplo 373: exitoso (prob: 0.7126), Real: exitoso
#   Ejemplo 374: no_exitoso (prob: 0.1799), Real: no_exitoso
#   Ejemplo 375: no_exitoso (prob: 0.0200), Real: no_exitoso
#   Ejemplo 376: exitoso (prob: 0.9609), Real: exitoso
#   Ejemplo 377: exitoso (prob: 0.9329), Real: exitoso
#   Ejemplo 378: no_exitoso (prob: 0.0323), Real: no_exitoso
#   Ejemplo 379: exitoso (prob: 0.9371), Real: exitoso
#   Ejemplo 380: exitoso (prob: 0.6259), Real: no_exitoso
#   Ejemplo 381: exitoso (prob: 0.9835), Real: exitoso
#   Ejemplo 382: exitoso (prob: 0.6305), Real: exitoso
#   Ejemplo 383: exitoso (prob: 0.9613), Real: exitoso
#   Ejemplo 384: exitoso (prob: 0.9848), Real: exitoso
#   Ejemplo 385: exitoso (prob: 0.7126), Real: exitoso
#   Ejemplo 386: exitoso (prob: 0.9934), Real: exitoso
#   Ejemplo 387: exitoso (prob: 0.9889), Real: exitoso
#   Ejemplo 388: no_exitoso (prob: 0.0308), Real: no_exitoso
#   Ejemplo 389: no_exitoso (prob: 0.1480), Real: no_exitoso
#   Ejemplo 390: no_exitoso (prob: 0.4012), Real: exitoso
#   Ejemplo 391: no_exitoso (prob: 0.0705), Real: no_exitoso
#   Ejemplo 392: exitoso (prob: 0.9783), Real: exitoso
#   Ejemplo 393: no_exitoso (prob: 0.3560), Real: no_exitoso
#   Ejemplo 394: no_exitoso (prob: 0.2377), Real: no_exitoso
#   Ejemplo 395: no_exitoso (prob: 0.3150), Real: exitoso
#   Ejemplo 396: exitoso (prob: 0.8529), Real: exitoso
#   Ejemplo 397: no_exitoso (prob: 0.0710), Real: no_exitoso
#   Ejemplo 398: no_exitoso (prob: 0.0197), Real: no_exitoso
#   Ejemplo 399: no_exitoso (prob: 0.1607), Real: no_exitoso
#   Ejemplo 400: no_exitoso (prob: 0.0613), Real: no_exitoso
#   Ejemplo 401: exitoso (prob: 0.8372), Real: exitoso
#   Ejemplo 402: no_exitoso (prob: 0.3339), Real: no_exitoso
#   Ejemplo 403: exitoso (prob: 0.6927), Real: exitoso
#   Ejemplo 404: exitoso (prob: 0.8945), Real: no_exitoso
#   Ejemplo 405: exitoso (prob: 0.7058), Real: exitoso
#   Ejemplo 406: exitoso (prob: 0.9370), Real: no_exitoso
#   Ejemplo 407: exitoso (prob: 0.9711), Real: exitoso
#   Ejemplo 408: no_exitoso (prob: 0.1587), Real: no_exitoso
#   Ejemplo 409: no_exitoso (prob: 0.2450), Real: no_exitoso
#   Ejemplo 410: exitoso (prob: 0.9692), Real: exitoso
#   Ejemplo 411: no_exitoso (prob: 0.0813), Real: exitoso
#   Ejemplo 412: no_exitoso (prob: 0.2767), Real: exitoso
#   Ejemplo 413: exitoso (prob: 0.8449), Real: exitoso
#   Ejemplo 414: exitoso (prob: 0.8097), Real: exitoso
#   Ejemplo 415: no_exitoso (prob: 0.0587), Real: no_exitoso
#   Ejemplo 416: exitoso (prob: 0.7683), Real: exitoso
#   Ejemplo 417: no_exitoso (prob: 0.0530), Real: no_exitoso
#   Ejemplo 418: no_exitoso (prob: 0.0280), Real: no_exitoso
#   Ejemplo 419: no_exitoso (prob: 0.2484), Real: no_exitoso
#   Ejemplo 420: no_exitoso (prob: 0.2987), Real: no_exitoso
#   Ejemplo 421: no_exitoso (prob: 0.0294), Real: no_exitoso
#   Ejemplo 422: exitoso (prob: 0.8960), Real: exitoso
#   Ejemplo 423: no_exitoso (prob: 0.0416), Real: no_exitoso
#   Ejemplo 424: no_exitoso (prob: 0.3935), Real: no_exitoso
#   Ejemplo 425: no_exitoso (prob: 0.1417), Real: no_exitoso
#   Ejemplo 426: exitoso (prob: 0.8865), Real: exitoso
#   Ejemplo 427: exitoso (prob: 0.9653), Real: exitoso
#   Ejemplo 428: no_exitoso (prob: 0.2948), Real: exitoso
#   Ejemplo 429: no_exitoso (prob: 0.3773), Real: no_exitoso
#   Ejemplo 430: no_exitoso (prob: 0.0249), Real: no_exitoso
#   Ejemplo 431: no_exitoso (prob: 0.4426), Real: no_exitoso
#   Ejemplo 432: no_exitoso (prob: 0.0509), Real: no_exitoso
#   Ejemplo 433: no_exitoso (prob: 0.0166), Real: no_exitoso
#   Ejemplo 434: no_exitoso (prob: 0.1290), Real: no_exitoso
#   Ejemplo 435: exitoso (prob: 0.8193), Real: exitoso
#   Ejemplo 436: exitoso (prob: 0.9170), Real: exitoso
#   Ejemplo 437: exitoso (prob: 0.6810), Real: exitoso
#   Ejemplo 438: exitoso (prob: 0.9450), Real: exitoso
#   Ejemplo 439: exitoso (prob: 0.7009), Real: exitoso
#   Ejemplo 440: exitoso (prob: 0.7631), Real: exitoso
#   Ejemplo 441: exitoso (prob: 0.9511), Real: exitoso
#   Ejemplo 442: exitoso (prob: 0.8517), Real: no_exitoso
#   Ejemplo 443: exitoso (prob: 0.8960), Real: exitoso
#   Ejemplo 444: no_exitoso (prob: 0.3913), Real: no_exitoso
#   Ejemplo 445: no_exitoso (prob: 0.0238), Real: no_exitoso
#   Ejemplo 446: exitoso (prob: 0.7700), Real: exitoso
#   Ejemplo 447: no_exitoso (prob: 0.1802), Real: no_exitoso
#   Ejemplo 448: exitoso (prob: 0.8359), Real: exitoso
#   Ejemplo 449: exitoso (prob: 0.9467), Real: exitoso
#   Ejemplo 450: exitoso (prob: 0.6379), Real: no_exitoso
#   Ejemplo 451: no_exitoso (prob: 0.0183), Real: no_exitoso
#   Ejemplo 452: no_exitoso (prob: 0.0778), Real: no_exitoso
#   Ejemplo 453: exitoso (prob: 0.9850), Real: exitoso
#   Ejemplo 454: exitoso (prob: 0.9790), Real: exitoso
#   Ejemplo 455: exitoso (prob: 0.7007), Real: no_exitoso
#   Ejemplo 456: no_exitoso (prob: 0.0257), Real: no_exitoso
#   Ejemplo 457: exitoso (prob: 0.9870), Real: exitoso
#   Ejemplo 458: exitoso (prob: 0.9609), Real: exitoso
#   Ejemplo 459: no_exitoso (prob: 0.1095), Real: no_exitoso
#   Ejemplo 460: no_exitoso (prob: 0.0966), Real: no_exitoso
#   Ejemplo 461: no_exitoso (prob: 0.1318), Real: no_exitoso
#   Ejemplo 462: no_exitoso (prob: 0.0135), Real: no_exitoso
#   Ejemplo 463: exitoso (prob: 0.7272), Real: exitoso
#   Ejemplo 464: no_exitoso (prob: 0.1538), Real: no_exitoso
#   Ejemplo 465: exitoso (prob: 0.8374), Real: exitoso
#   Ejemplo 466: exitoso (prob: 0.5595), Real: exitoso
#   Ejemplo 467: no_exitoso (prob: 0.4802), Real: no_exitoso
#   Ejemplo 468: exitoso (prob: 0.5759), Real: exitoso
#   Ejemplo 469: no_exitoso (prob: 0.0711), Real: no_exitoso
#   Ejemplo 470: no_exitoso (prob: 0.0864), Real: no_exitoso
#   Ejemplo 471: no_exitoso (prob: 0.1391), Real: no_exitoso
#   Ejemplo 472: exitoso (prob: 0.8511), Real: exitoso
#   Ejemplo 473: no_exitoso (prob: 0.0541), Real: no_exitoso
#   Ejemplo 474: no_exitoso (prob: 0.4920), Real: no_exitoso
#   Ejemplo 475: no_exitoso (prob: 0.0297), Real: no_exitoso
#   Ejemplo 476: exitoso (prob: 0.9626), Real: no_exitoso
#   Ejemplo 477: no_exitoso (prob: 0.0668), Real: no_exitoso
#   Ejemplo 478: no_exitoso (prob: 0.1843), Real: no_exitoso
#   Ejemplo 479: no_exitoso (prob: 0.0251), Real: no_exitoso
#   Ejemplo 480: exitoso (prob: 0.8529), Real: exitoso
#   Ejemplo 481: no_exitoso (prob: 0.1557), Real: no_exitoso
#   Ejemplo 482: no_exitoso (prob: 0.1875), Real: no_exitoso
#   Ejemplo 483: no_exitoso (prob: 0.3588), Real: no_exitoso
#   Ejemplo 484: exitoso (prob: 0.9598), Real: exitoso
#   Ejemplo 485: exitoso (prob: 0.7584), Real: no_exitoso
#   Ejemplo 486: no_exitoso (prob: 0.2056), Real: exitoso
#   Ejemplo 487: exitoso (prob: 0.9662), Real: exitoso
#   Ejemplo 488: no_exitoso (prob: 0.1587), Real: no_exitoso
#   Ejemplo 489: exitoso (prob: 0.8988), Real: exitoso
#   Ejemplo 490: no_exitoso (prob: 0.0259), Real: no_exitoso
#   Ejemplo 491: no_exitoso (prob: 0.2251), Real: no_exitoso
#   Ejemplo 492: no_exitoso (prob: 0.0211), Real: no_exitoso
#   Ejemplo 493: exitoso (prob: 0.9703), Real: exitoso
#   Ejemplo 494: no_exitoso (prob: 0.0824), Real: no_exitoso
#   Ejemplo 495: exitoso (prob: 0.8335), Real: exitoso
#   Ejemplo 496: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 497: no_exitoso (prob: 0.0297), Real: no_exitoso
#   Ejemplo 498: no_exitoso (prob: 0.4592), Real: exitoso
#   Ejemplo 499: no_exitoso (prob: 0.1021), Real: no_exitoso
#   Ejemplo 500: exitoso (prob: 0.9822), Real: exitoso
#   Ejemplo 501: exitoso (prob: 0.6577), Real: exitoso
#   Ejemplo 502: exitoso (prob: 0.6859), Real: no_exitoso
#   Ejemplo 503: no_exitoso (prob: 0.0952), Real: no_exitoso
#   Ejemplo 504: exitoso (prob: 0.5334), Real: exitoso
#   Ejemplo 505: no_exitoso (prob: 0.2251), Real: no_exitoso
#   Ejemplo 506: no_exitoso (prob: 0.4795), Real: exitoso
#   Ejemplo 507: no_exitoso (prob: 0.1915), Real: no_exitoso
#   Ejemplo 508: no_exitoso (prob: 0.2459), Real: exitoso
#   Ejemplo 509: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 510: exitoso (prob: 0.9665), Real: exitoso
#   Ejemplo 511: no_exitoso (prob: 0.1373), Real: no_exitoso
#   Ejemplo 512: exitoso (prob: 0.8157), Real: exitoso
#   Ejemplo 513: no_exitoso (prob: 0.1126), Real: exitoso
#   Ejemplo 514: exitoso (prob: 0.5017), Real: exitoso
#   Ejemplo 515: no_exitoso (prob: 0.3090), Real: exitoso
#   Ejemplo 516: no_exitoso (prob: 0.1118), Real: no_exitoso
#   Ejemplo 517: no_exitoso (prob: 0.2479), Real: exitoso
#   Ejemplo 518: no_exitoso (prob: 0.0419), Real: no_exitoso
#   Ejemplo 519: no_exitoso (prob: 0.0703), Real: no_exitoso
#   Ejemplo 520: no_exitoso (prob: 0.0636), Real: no_exitoso
#   Ejemplo 521: exitoso (prob: 0.9925), Real: exitoso
#   Ejemplo 522: no_exitoso (prob: 0.3029), Real: no_exitoso
#   Ejemplo 523: exitoso (prob: 0.8838), Real: exitoso
#   Ejemplo 524: no_exitoso (prob: 0.0208), Real: no_exitoso
#   Ejemplo 525: exitoso (prob: 0.9928), Real: exitoso
#   Ejemplo 526: exitoso (prob: 0.9869), Real: exitoso
#   Ejemplo 527: exitoso (prob: 0.8807), Real: exitoso
#   Ejemplo 528: no_exitoso (prob: 0.4828), Real: no_exitoso
#   Ejemplo 529: no_exitoso (prob: 0.0727), Real: exitoso
#   Ejemplo 530: exitoso (prob: 0.9608), Real: exitoso
#   Ejemplo 531: no_exitoso (prob: 0.0262), Real: no_exitoso
#   Ejemplo 532: no_exitoso (prob: 0.0588), Real: no_exitoso
#   Ejemplo 533: no_exitoso (prob: 0.0875), Real: no_exitoso
#   Ejemplo 534: exitoso (prob: 0.9769), Real: exitoso
#   Ejemplo 535: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 536: no_exitoso (prob: 0.1359), Real: no_exitoso
#   Ejemplo 537: exitoso (prob: 0.9769), Real: exitoso
#   Ejemplo 538: no_exitoso (prob: 0.0750), Real: no_exitoso
#   Ejemplo 539: exitoso (prob: 0.5051), Real: exitoso
#   Ejemplo 540: exitoso (prob: 0.9287), Real: exitoso
#   Ejemplo 541: no_exitoso (prob: 0.0790), Real: no_exitoso
#   Ejemplo 542: no_exitoso (prob: 0.0710), Real: no_exitoso
#   Ejemplo 543: exitoso (prob: 0.9462), Real: no_exitoso
#   Ejemplo 544: no_exitoso (prob: 0.1220), Real: no_exitoso
#   Ejemplo 545: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 546: no_exitoso (prob: 0.0208), Real: no_exitoso
#   Ejemplo 547: exitoso (prob: 0.8989), Real: exitoso
#   Ejemplo 548: no_exitoso (prob: 0.0225), Real: no_exitoso
#   Ejemplo 549: no_exitoso (prob: 0.4145), Real: no_exitoso
#   Ejemplo 550: no_exitoso (prob: 0.3891), Real: exitoso
#   Ejemplo 551: exitoso (prob: 0.7283), Real: exitoso
#   Ejemplo 552: exitoso (prob: 0.9395), Real: exitoso
#   Ejemplo 553: no_exitoso (prob: 0.3673), Real: no_exitoso
#   Ejemplo 554: no_exitoso (prob: 0.1578), Real: no_exitoso
#   Ejemplo 555: exitoso (prob: 0.9698), Real: exitoso
#   Ejemplo 556: no_exitoso (prob: 0.0969), Real: no_exitoso
#   Ejemplo 557: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 558: no_exitoso (prob: 0.0317), Real: no_exitoso
#   Ejemplo 559: exitoso (prob: 0.5586), Real: exitoso
#   Ejemplo 560: no_exitoso (prob: 0.0807), Real: no_exitoso
#   Ejemplo 561: exitoso (prob: 0.9665), Real: exitoso
#   Ejemplo 562: no_exitoso (prob: 0.0560), Real: no_exitoso
#   Ejemplo 563: no_exitoso (prob: 0.2105), Real: no_exitoso
#   Ejemplo 564: exitoso (prob: 0.9871), Real: exitoso
#   Ejemplo 565: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 566: exitoso (prob: 0.6653), Real: exitoso
#   Ejemplo 567: no_exitoso (prob: 0.0929), Real: no_exitoso
#   Ejemplo 568: exitoso (prob: 0.9502), Real: exitoso
#   Ejemplo 569: exitoso (prob: 0.5287), Real: no_exitoso
#   Ejemplo 570: exitoso (prob: 0.8372), Real: exitoso
#   Ejemplo 571: exitoso (prob: 0.9396), Real: no_exitoso
#   Ejemplo 572: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 573: no_exitoso (prob: 0.1323), Real: no_exitoso
#   Ejemplo 574: no_exitoso (prob: 0.0251), Real: no_exitoso
#   Ejemplo 575: exitoso (prob: 0.9164), Real: exitoso
#   Ejemplo 576: no_exitoso (prob: 0.1301), Real: exitoso
#   Ejemplo 577: exitoso (prob: 0.6483), Real: exitoso
#   Ejemplo 578: no_exitoso (prob: 0.1391), Real: no_exitoso
#   Ejemplo 579: no_exitoso (prob: 0.1595), Real: no_exitoso
#   Ejemplo 580: exitoso (prob: 0.8000), Real: exitoso
#   Ejemplo 581: exitoso (prob: 0.9937), Real: exitoso
#   Ejemplo 582: exitoso (prob: 0.8402), Real: no_exitoso
#   Ejemplo 583: no_exitoso (prob: 0.0150), Real: no_exitoso
#   Ejemplo 584: exitoso (prob: 0.9876), Real: exitoso
#   Ejemplo 585: exitoso (prob: 0.6904), Real: exitoso
#   Ejemplo 586: exitoso (prob: 0.7894), Real: exitoso
#   Ejemplo 587: no_exitoso (prob: 0.3150), Real: no_exitoso
#   Ejemplo 588: no_exitoso (prob: 0.1657), Real: no_exitoso
#   Ejemplo 589: no_exitoso (prob: 0.1621), Real: no_exitoso
#   Ejemplo 590: no_exitoso (prob: 0.2250), Real: no_exitoso
#   Ejemplo 591: no_exitoso (prob: 0.1325), Real: no_exitoso
#   Ejemplo 592: exitoso (prob: 0.6493), Real: exitoso
#   Ejemplo 593: exitoso (prob: 0.7347), Real: exitoso
#   Ejemplo 594: no_exitoso (prob: 0.0147), Real: no_exitoso
#   Ejemplo 595: no_exitoso (prob: 0.1475), Real: no_exitoso
#   Ejemplo 596: exitoso (prob: 0.8743), Real: exitoso
#   Ejemplo 597: no_exitoso (prob: 0.0348), Real: no_exitoso
#   Ejemplo 598: exitoso (prob: 0.9927), Real: exitoso
#   Ejemplo 599: exitoso (prob: 0.9725), Real: exitoso
#   Ejemplo 600: exitoso (prob: 0.9872), Real: exitoso
#   Ejemplo 601: no_exitoso (prob: 0.4361), Real: exitoso
#   Ejemplo 602: no_exitoso (prob: 0.3528), Real: exitoso
#   Ejemplo 603: exitoso (prob: 0.7444), Real: exitoso
#   Ejemplo 604: exitoso (prob: 0.6580), Real: exitoso
#   Ejemplo 605: exitoso (prob: 0.8901), Real: exitoso
#   Ejemplo 606: no_exitoso (prob: 0.1570), Real: no_exitoso
#   Ejemplo 607: no_exitoso (prob: 0.0425), Real: no_exitoso
#   Ejemplo 608: exitoso (prob: 0.9609), Real: exitoso
#   Ejemplo 609: exitoso (prob: 0.9164), Real: exitoso
#   Ejemplo 610: no_exitoso (prob: 0.1325), Real: no_exitoso
#   Ejemplo 611: no_exitoso (prob: 0.0295), Real: no_exitoso
#   Ejemplo 612: exitoso (prob: 0.9854), Real: exitoso
#   Ejemplo 613: exitoso (prob: 0.8050), Real: exitoso
#   Ejemplo 614: exitoso (prob: 0.9164), Real: exitoso
#   Ejemplo 615: no_exitoso (prob: 0.1351), Real: no_exitoso
#   Ejemplo 616: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 617: no_exitoso (prob: 0.2733), Real: no_exitoso
#   Ejemplo 618: no_exitoso (prob: 0.0297), Real: no_exitoso
#   Ejemplo 619: exitoso (prob: 0.5804), Real: no_exitoso
#   Ejemplo 620: exitoso (prob: 0.9819), Real: exitoso
#   Ejemplo 621: exitoso (prob: 0.7527), Real: exitoso
#   Ejemplo 622: exitoso (prob: 0.9609), Real: exitoso
#   Ejemplo 623: no_exitoso (prob: 0.3090), Real: no_exitoso
#   Ejemplo 624: exitoso (prob: 0.9748), Real: exitoso
#   Ejemplo 625: exitoso (prob: 0.9935), Real: exitoso
#   Ejemplo 626: no_exitoso (prob: 0.0208), Real: no_exitoso
#   Ejemplo 627: exitoso (prob: 0.5790), Real: exitoso
#   Ejemplo 628: exitoso (prob: 0.8766), Real: exitoso
#   Ejemplo 629: no_exitoso (prob: 0.1460), Real: no_exitoso
#   Ejemplo 630: exitoso (prob: 0.9534), Real: exitoso
#   Ejemplo 631: exitoso (prob: 0.9841), Real: exitoso
#   Ejemplo 632: no_exitoso (prob: 0.1368), Real: no_exitoso
#   Ejemplo 633: no_exitoso (prob: 0.0459), Real: no_exitoso
#   Ejemplo 634: exitoso (prob: 0.8864), Real: no_exitoso
#   Ejemplo 635: exitoso (prob: 0.6203), Real: exitoso
#   Ejemplo 636: exitoso (prob: 0.9608), Real: exitoso
#   Ejemplo 637: exitoso (prob: 0.9919), Real: exitoso
#   Ejemplo 638: no_exitoso (prob: 0.1670), Real: no_exitoso
#   Ejemplo 639: no_exitoso (prob: 0.1794), Real: no_exitoso
#   Ejemplo 640: no_exitoso (prob: 0.3829), Real: no_exitoso
#   Ejemplo 641: no_exitoso (prob: 0.1223), Real: no_exitoso
#   Ejemplo 642: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 643: no_exitoso (prob: 0.4273), Real: no_exitoso
#   Ejemplo 644: no_exitoso (prob: 0.1067), Real: no_exitoso
#   Ejemplo 645: no_exitoso (prob: 0.0160), Real: no_exitoso
#   Ejemplo 646: no_exitoso (prob: 0.1223), Real: no_exitoso
#   Ejemplo 647: no_exitoso (prob: 0.0260), Real: no_exitoso
#   Ejemplo 648: exitoso (prob: 0.8849), Real: exitoso
#   Ejemplo 649: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 650: no_exitoso (prob: 0.0750), Real: no_exitoso
#   Ejemplo 651: no_exitoso (prob: 0.0883), Real: exitoso
#   Ejemplo 652: no_exitoso (prob: 0.0546), Real: no_exitoso
#   Ejemplo 653: exitoso (prob: 0.6598), Real: exitoso
#   Ejemplo 654: no_exitoso (prob: 0.0662), Real: no_exitoso
#   Ejemplo 655: exitoso (prob: 0.9136), Real: exitoso
#   Ejemplo 656: exitoso (prob: 0.7323), Real: exitoso
#   Ejemplo 657: no_exitoso (prob: 0.1742), Real: no_exitoso
#   Ejemplo 658: no_exitoso (prob: 0.3807), Real: no_exitoso
#   Ejemplo 659: no_exitoso (prob: 0.3150), Real: no_exitoso
#   Ejemplo 660: no_exitoso (prob: 0.2050), Real: exitoso
#   Ejemplo 661: exitoso (prob: 0.9486), Real: exitoso
#   Ejemplo 662: no_exitoso (prob: 0.0693), Real: no_exitoso
#   Ejemplo 663: no_exitoso (prob: 0.3507), Real: no_exitoso
#   Ejemplo 664: no_exitoso (prob: 0.0209), Real: no_exitoso
#   Ejemplo 665: no_exitoso (prob: 0.0321), Real: no_exitoso
#   Ejemplo 666: no_exitoso (prob: 0.0234), Real: no_exitoso
#   Ejemplo 667: no_exitoso (prob: 0.0731), Real: no_exitoso
#   Ejemplo 668: exitoso (prob: 0.8850), Real: exitoso
#   Ejemplo 669: exitoso (prob: 0.9568), Real: exitoso
#   Ejemplo 670: no_exitoso (prob: 0.0849), Real: no_exitoso
#   Ejemplo 671: exitoso (prob: 0.9687), Real: exitoso
#   Ejemplo 672: exitoso (prob: 0.6136), Real: exitoso
#   Ejemplo 673: no_exitoso (prob: 0.1604), Real: no_exitoso
#   Ejemplo 674: exitoso (prob: 0.7616), Real: exitoso
#   Ejemplo 675: exitoso (prob: 0.9395), Real: exitoso
#   Ejemplo 676: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 677: no_exitoso (prob: 0.1213), Real: no_exitoso
#   Ejemplo 678: no_exitoso (prob: 0.0900), Real: no_exitoso
#   Ejemplo 679: exitoso (prob: 0.8420), Real: no_exitoso
#   Ejemplo 680: no_exitoso (prob: 0.0669), Real: no_exitoso
#   Ejemplo 681: exitoso (prob: 0.8566), Real: exitoso
#   Ejemplo 682: no_exitoso (prob: 0.4433), Real: no_exitoso
#   Ejemplo 683: no_exitoso (prob: 0.0769), Real: no_exitoso
#   Ejemplo 684: exitoso (prob: 0.9838), Real: exitoso
#   Ejemplo 685: exitoso (prob: 0.9769), Real: exitoso
#   Ejemplo 686: exitoso (prob: 0.6715), Real: exitoso
#   Ejemplo 687: no_exitoso (prob: 0.0372), Real: no_exitoso
#   Ejemplo 688: no_exitoso (prob: 0.3021), Real: no_exitoso
#   Ejemplo 689: exitoso (prob: 0.9244), Real: exitoso
#   Ejemplo 690: exitoso (prob: 0.5590), Real: exitoso
#   Ejemplo 691: no_exitoso (prob: 0.0996), Real: no_exitoso
#   Ejemplo 692: no_exitoso (prob: 0.0177), Real: no_exitoso
#   Ejemplo 693: no_exitoso (prob: 0.0996), Real: no_exitoso
#   Ejemplo 694: exitoso (prob: 0.7174), Real: exitoso
#   Ejemplo 695: no_exitoso (prob: 0.1169), Real: no_exitoso
#   Ejemplo 696: no_exitoso (prob: 0.0878), Real: no_exitoso
#   Ejemplo 697: exitoso (prob: 0.9649), Real: exitoso
#   Ejemplo 698: no_exitoso (prob: 0.2479), Real: no_exitoso
#   Ejemplo 699: exitoso (prob: 0.8711), Real: no_exitoso
#   Ejemplo 700: exitoso (prob: 0.9395), Real: exitoso
#   Ejemplo 701: exitoso (prob: 0.9845), Real: exitoso
#   Ejemplo 702: no_exitoso (prob: 0.1043), Real: no_exitoso
#   Ejemplo 703: exitoso (prob: 0.7827), Real: exitoso
#   Ejemplo 704: no_exitoso (prob: 0.2116), Real: exitoso
#   Ejemplo 705: exitoso (prob: 0.9838), Real: exitoso
#   Ejemplo 706: no_exitoso (prob: 0.2677), Real: exitoso
#   Ejemplo 707: exitoso (prob: 0.9789), Real: exitoso
#   Ejemplo 708: no_exitoso (prob: 0.3904), Real: exitoso
#   Ejemplo 709: no_exitoso (prob: 0.1822), Real: no_exitoso
#   Ejemplo 710: no_exitoso (prob: 0.1722), Real: no_exitoso
#   Ejemplo 711: exitoso (prob: 0.6461), Real: exitoso
#   Ejemplo 712: exitoso (prob: 0.8913), Real: exitoso
#   Ejemplo 713: no_exitoso (prob: 0.4200), Real: no_exitoso
#   Ejemplo 714: exitoso (prob: 0.5251), Real: exitoso
#   Ejemplo 715: exitoso (prob: 0.9287), Real: exitoso
#   Ejemplo 716: no_exitoso (prob: 0.1374), Real: no_exitoso
#   Ejemplo 717: no_exitoso (prob: 0.0491), Real: no_exitoso
#   Ejemplo 718: exitoso (prob: 0.8945), Real: exitoso
#   Ejemplo 719: no_exitoso (prob: 0.0208), Real: no_exitoso
#   Ejemplo 720: exitoso (prob: 0.5673), Real: exitoso
#   Ejemplo 721: no_exitoso (prob: 0.1614), Real: no_exitoso
#   Ejemplo 722: no_exitoso (prob: 0.1556), Real: exitoso
#   Ejemplo 723: exitoso (prob: 0.7717), Real: exitoso
#   Ejemplo 724: no_exitoso (prob: 0.0631), Real: no_exitoso
#   Ejemplo 725: exitoso (prob: 0.9461), Real: exitoso
#   Ejemplo 726: exitoso (prob: 0.9894), Real: exitoso
#   Ejemplo 727: no_exitoso (prob: 0.3496), Real: no_exitoso
#   Ejemplo 728: no_exitoso (prob: 0.2056), Real: no_exitoso
#   Ejemplo 729: no_exitoso (prob: 0.0702), Real: no_exitoso
#   Ejemplo 730: no_exitoso (prob: 0.2251), Real: exitoso
#   Ejemplo 731: no_exitoso (prob: 0.0486), Real: no_exitoso
#   Ejemplo 732: no_exitoso (prob: 0.0260), Real: no_exitoso
#   Ejemplo 733: exitoso (prob: 0.9618), Real: exitoso
#   Ejemplo 734: no_exitoso (prob: 0.1372), Real: no_exitoso
#   Ejemplo 735: no_exitoso (prob: 0.0693), Real: no_exitoso
#   Ejemplo 736: exitoso (prob: 0.9867), Real: exitoso
#   Ejemplo 737: no_exitoso (prob: 0.0178), Real: no_exitoso
#   Ejemplo 738: exitoso (prob: 0.9396), Real: exitoso
#   Ejemplo 739: no_exitoso (prob: 0.0244), Real: no_exitoso
#   Ejemplo 740: no_exitoso (prob: 0.3215), Real: no_exitoso
#   Ejemplo 741: no_exitoso (prob: 0.0327), Real: no_exitoso
#   Ejemplo 742: no_exitoso (prob: 0.3306), Real: exitoso
#   Ejemplo 743: no_exitoso (prob: 0.2139), Real: no_exitoso
#   Ejemplo 744: exitoso (prob: 0.9568), Real: exitoso
#   Ejemplo 745: no_exitoso (prob: 0.0197), Real: no_exitoso
#   Ejemplo 746: no_exitoso (prob: 0.3090), Real: no_exitoso
#   Ejemplo 747: exitoso (prob: 0.9047), Real: exitoso
#   Ejemplo 748: no_exitoso (prob: 0.0643), Real: no_exitoso
#   Ejemplo 749: no_exitoso (prob: 0.1314), Real: no_exitoso
#   Ejemplo 750: exitoso (prob: 0.9822), Real: exitoso
#   Ejemplo 751: exitoso (prob: 0.7386), Real: exitoso
#   Ejemplo 752: no_exitoso (prob: 0.2258), Real: no_exitoso
#   Ejemplo 753: no_exitoso (prob: 0.3589), Real: no_exitoso
#   Ejemplo 754: exitoso (prob: 0.9611), Real: exitoso
#   Ejemplo 755: no_exitoso (prob: 0.4288), Real: no_exitoso
#   Ejemplo 756: no_exitoso (prob: 0.0157), Real: no_exitoso
#   Ejemplo 757: exitoso (prob: 0.8721), Real: exitoso
#   Ejemplo 758: exitoso (prob: 0.9515), Real: exitoso
#   Ejemplo 759: no_exitoso (prob: 0.2281), Real: no_exitoso
#   Ejemplo 760: no_exitoso (prob: 0.1517), Real: no_exitoso
#   Ejemplo 761: no_exitoso (prob: 0.0363), Real: no_exitoso
#   Ejemplo 762: exitoso (prob: 0.9769), Real: exitoso
#   Ejemplo 763: no_exitoso (prob: 0.2073), Real: exitoso
#   Ejemplo 764: no_exitoso (prob: 0.3133), Real: no_exitoso
#   Ejemplo 765: exitoso (prob: 0.7473), Real: exitoso
#   Ejemplo 766: exitoso (prob: 0.8388), Real: exitoso
#   Ejemplo 767: exitoso (prob: 0.7256), Real: no_exitoso
#   Ejemplo 768: no_exitoso (prob: 0.0250), Real: no_exitoso
#   Ejemplo 769: no_exitoso (prob: 0.2251), Real: no_exitoso
#   Ejemplo 770: no_exitoso (prob: 0.1475), Real: no_exitoso
#   Ejemplo 771: no_exitoso (prob: 0.0206), Real: no_exitoso
#   Ejemplo 772: exitoso (prob: 0.9936), Real: exitoso
#   Ejemplo 773: no_exitoso (prob: 0.1403), Real: no_exitoso
#   Ejemplo 774: exitoso (prob: 0.9928), Real: exitoso
#   Ejemplo 775: no_exitoso (prob: 0.1437), Real: no_exitoso
#   Ejemplo 776: no_exitoso (prob: 0.3052), Real: exitoso
#   Ejemplo 777: no_exitoso (prob: 0.1840), Real: no_exitoso
#   Ejemplo 778: no_exitoso (prob: 0.0366), Real: exitoso
#   Ejemplo 779: exitoso (prob: 0.8887), Real: exitoso
#   Ejemplo 780: no_exitoso (prob: 0.2323), Real: exitoso
#   Ejemplo 781: no_exitoso (prob: 0.0486), Real: no_exitoso
#   Ejemplo 782: exitoso (prob: 0.9285), Real: exitoso
#   Ejemplo 783: no_exitoso (prob: 0.3350), Real: no_exitoso
#   Ejemplo 784: exitoso (prob: 0.6655), Real: no_exitoso
#   Ejemplo 785: no_exitoso (prob: 0.0488), Real: no_exitoso
#   Ejemplo 786: exitoso (prob: 0.9122), Real: exitoso
#   Ejemplo 787: no_exitoso (prob: 0.3112), Real: no_exitoso
#   Ejemplo 788: no_exitoso (prob: 0.0283), Real: no_exitoso
#   Ejemplo 789: exitoso (prob: 0.9698), Real: exitoso
#   Ejemplo 790: exitoso (prob: 0.9876), Real: exitoso
#   Ejemplo 791: no_exitoso (prob: 0.0501), Real: no_exitoso
#   Ejemplo 792: exitoso (prob: 0.9720), Real: exitoso
#   Ejemplo 793: no_exitoso (prob: 0.0229), Real: no_exitoso
#   Ejemplo 794: exitoso (prob: 0.5891), Real: exitoso
#   Ejemplo 795: no_exitoso (prob: 0.0729), Real: no_exitoso
#   Ejemplo 796: no_exitoso (prob: 0.0727), Real: no_exitoso
#   Ejemplo 797: exitoso (prob: 0.9822), Real: exitoso
#   Ejemplo 798: exitoso (prob: 0.9576), Real: exitoso
#   Ejemplo 799: no_exitoso (prob: 0.1095), Real: no_exitoso
#   Ejemplo 800: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 801: exitoso (prob: 0.8595), Real: exitoso
#   Ejemplo 802: exitoso (prob: 0.9200), Real: no_exitoso
#   Ejemplo 803: exitoso (prob: 0.8864), Real: no_exitoso
#   Ejemplo 804: exitoso (prob: 0.9927), Real: exitoso
#   Ejemplo 805: no_exitoso (prob: 0.0329), Real: no_exitoso
#   Ejemplo 806: exitoso (prob: 0.8748), Real: exitoso
#   Ejemplo 807: no_exitoso (prob: 0.0643), Real: no_exitoso
#   Ejemplo 808: no_exitoso (prob: 0.2948), Real: exitoso
#   Ejemplo 809: no_exitoso (prob: 0.1587), Real: no_exitoso
#   Ejemplo 810: no_exitoso (prob: 0.1221), Real: exitoso
#   Ejemplo 811: exitoso (prob: 0.5411), Real: exitoso
#   Ejemplo 812: exitoso (prob: 0.9933), Real: exitoso
#   Ejemplo 813: exitoso (prob: 0.9139), Real: no_exitoso
#   Ejemplo 814: no_exitoso (prob: 0.0471), Real: no_exitoso
#   Ejemplo 815: no_exitoso (prob: 0.3150), Real: no_exitoso
#   Ejemplo 816: exitoso (prob: 0.5460), Real: no_exitoso
#   Ejemplo 817: no_exitoso (prob: 0.1293), Real: no_exitoso
#   Ejemplo 818: exitoso (prob: 0.8572), Real: exitoso
#   Ejemplo 819: exitoso (prob: 0.9751), Real: exitoso
#   Ejemplo 820: exitoso (prob: 0.7087), Real: exitoso
#   Ejemplo 821: exitoso (prob: 0.6081), Real: exitoso
#   Ejemplo 822: no_exitoso (prob: 0.2992), Real: no_exitoso
#   Ejemplo 823: no_exitoso (prob: 0.0283), Real: no_exitoso
#   Ejemplo 824: exitoso (prob: 0.9610), Real: exitoso
#   Ejemplo 825: no_exitoso (prob: 0.0416), Real: no_exitoso
#   Ejemplo 826: no_exitoso (prob: 0.4576), Real: exitoso
#   Ejemplo 827: exitoso (prob: 0.8561), Real: exitoso
#   Ejemplo 828: no_exitoso (prob: 0.0316), Real: no_exitoso
#   Ejemplo 829: no_exitoso (prob: 0.0936), Real: no_exitoso
#   Ejemplo 830: exitoso (prob: 0.8558), Real: exitoso
#   Ejemplo 831: exitoso (prob: 0.6059), Real: no_exitoso
#   Ejemplo 832: exitoso (prob: 0.8359), Real: exitoso
#   Ejemplo 833: no_exitoso (prob: 0.0569), Real: no_exitoso
#   Ejemplo 834: exitoso (prob: 0.9669), Real: exitoso
#   Ejemplo 835: exitoso (prob: 0.6662), Real: exitoso
#   Ejemplo 836: exitoso (prob: 0.9881), Real: exitoso
#   Ejemplo 837: exitoso (prob: 0.8407), Real: exitoso
#   Ejemplo 838: exitoso (prob: 0.7430), Real: exitoso
#   Ejemplo 839: exitoso (prob: 0.9703), Real: exitoso
#   Ejemplo 840: no_exitoso (prob: 0.0611), Real: no_exitoso
#   Ejemplo 841: exitoso (prob: 0.7954), Real: exitoso
#   Ejemplo 842: no_exitoso (prob: 0.1550), Real: no_exitoso
#   Ejemplo 843: no_exitoso (prob: 0.1659), Real: no_exitoso
#   Ejemplo 844: no_exitoso (prob: 0.0208), Real: no_exitoso
#   Ejemplo 845: exitoso (prob: 0.8950), Real: exitoso
#   Ejemplo 846: exitoso (prob: 0.9870), Real: exitoso
#   Ejemplo 847: exitoso (prob: 0.9568), Real: exitoso
#   Ejemplo 848: no_exitoso (prob: 0.1224), Real: exitoso
#   Ejemplo 849: no_exitoso (prob: 0.2213), Real: no_exitoso
#   Ejemplo 850: no_exitoso (prob: 0.0773), Real: no_exitoso
#   Ejemplo 851: no_exitoso (prob: 0.1521), Real: no_exitoso
#   Ejemplo 852: exitoso (prob: 0.9935), Real: exitoso
#   Ejemplo 853: no_exitoso (prob: 0.4870), Real: no_exitoso
#   Ejemplo 854: no_exitoso (prob: 0.3936), Real: no_exitoso
#   Ejemplo 855: no_exitoso (prob: 0.1785), Real: no_exitoso
#   Ejemplo 856: exitoso (prob: 0.9887), Real: exitoso
# ...
#   Ejemplo 34542: exitoso (prob: 0.7707), Real: no_exitoso
#   Ejemplo 34543: exitoso (prob: 0.9525), Real: exitoso
#   Ejemplo 34544: exitoso (prob: 0.9464), Real: exitoso
#   Ejemplo 34545: no_exitoso (prob: 0.1794), Real: no_exitoso
#   Ejemplo 34546: no_exitoso (prob: 0.0926), Real: no_exitoso
#   Ejemplo 34547: exitoso (prob: 0.7654), Real: exitoso
#   Ejemplo 34548: exitoso (prob: 0.9870), Real: exitoso
#   Ejemplo 34549: no_exitoso (prob: 0.0310), Real: no_exitoso
#   Ejemplo 34550: exitoso (prob: 0.9867), Real: exitoso
#   Ejemplo 34551: exitoso (prob: 0.7493), Real: no_exitoso
#   Ejemplo 34552: exitoso (prob: 0.8466), Real: exitoso
#   Ejemplo 34553: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 34554: no_exitoso (prob: 0.1519), Real: no_exitoso
#   Ejemplo 34555: exitoso (prob: 0.9503), Real: exitoso
#   Ejemplo 34556: no_exitoso (prob: 0.3929), Real: exitoso
#   Ejemplo 34557: exitoso (prob: 0.9827), Real: exitoso
#   Ejemplo 34558: exitoso (prob: 0.6289), Real: exitoso
#   Ejemplo 34559: no_exitoso (prob: 0.0270), Real: no_exitoso
#   Ejemplo 34560: no_exitoso (prob: 0.0237), Real: no_exitoso
#   Ejemplo 34561: no_exitoso (prob: 0.1347), Real: no_exitoso
#   Ejemplo 34562: no_exitoso (prob: 0.0870), Real: no_exitoso
#   Ejemplo 34563: no_exitoso (prob: 0.1751), Real: exitoso
#   Ejemplo 34564: exitoso (prob: 0.7088), Real: exitoso
#   Ejemplo 34565: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 34566: exitoso (prob: 0.9926), Real: exitoso
#   Ejemplo 34567: exitoso (prob: 0.9822), Real: exitoso
#   Ejemplo 34568: no_exitoso (prob: 0.0937), Real: no_exitoso
#   Ejemplo 34569: exitoso (prob: 0.8449), Real: exitoso
#   Ejemplo 34570: no_exitoso (prob: 0.0297), Real: no_exitoso
#   Ejemplo 34571: no_exitoso (prob: 0.0719), Real: no_exitoso
#   Ejemplo 34572: no_exitoso (prob: 0.0194), Real: no_exitoso
#   Ejemplo 34573: no_exitoso (prob: 0.1203), Real: no_exitoso
#   Ejemplo 34574: no_exitoso (prob: 0.2469), Real: no_exitoso
#   Ejemplo 34575: no_exitoso (prob: 0.4642), Real: exitoso
#   Ejemplo 34576: exitoso (prob: 0.9727), Real: exitoso
#   Ejemplo 34577: no_exitoso (prob: 0.0177), Real: no_exitoso
#   Ejemplo 34578: no_exitoso (prob: 0.1330), Real: no_exitoso
#   Ejemplo 34579: exitoso (prob: 0.6002), Real: exitoso
#   Ejemplo 34580: no_exitoso (prob: 0.3803), Real: no_exitoso
#   Ejemplo 34581: no_exitoso (prob: 0.0453), Real: no_exitoso
#   Ejemplo 34582: no_exitoso (prob: 0.0355), Real: no_exitoso
#   Ejemplo 34583: exitoso (prob: 0.9926), Real: exitoso
#   Ejemplo 34584: exitoso (prob: 0.8324), Real: exitoso
#   Ejemplo 34585: exitoso (prob: 0.9924), Real: exitoso
#   Ejemplo 34586: exitoso (prob: 0.6978), Real: exitoso
#   Ejemplo 34587: exitoso (prob: 0.8330), Real: exitoso
#   Ejemplo 34588: exitoso (prob: 0.8036), Real: exitoso
#   Ejemplo 34589: no_exitoso (prob: 0.0700), Real: no_exitoso
#   Ejemplo 34590: no_exitoso (prob: 0.0665), Real: no_exitoso
#   Ejemplo 34591: exitoso (prob: 0.8506), Real: exitoso
#   Ejemplo 34592: exitoso (prob: 0.9869), Real: exitoso
#   Ejemplo 34593: exitoso (prob: 0.5267), Real: no_exitoso
#   Ejemplo 34594: no_exitoso (prob: 0.1653), Real: no_exitoso
#   Ejemplo 34595: exitoso (prob: 0.8000), Real: no_exitoso
#   Ejemplo 34596: exitoso (prob: 0.6541), Real: exitoso
#   Ejemplo 34597: no_exitoso (prob: 0.0703), Real: no_exitoso
#   Ejemplo 34598: no_exitoso (prob: 0.2250), Real: no_exitoso
#   Ejemplo 34599: exitoso (prob: 0.8975), Real: no_exitoso
#   Ejemplo 34600: no_exitoso (prob: 0.4991), Real: no_exitoso
#   Ejemplo 34601: no_exitoso (prob: 0.2050), Real: no_exitoso
#   Ejemplo 34602: exitoso (prob: 0.9927), Real: exitoso
#   Ejemplo 34603: exitoso (prob: 0.6512), Real: exitoso
#   Ejemplo 34604: no_exitoso (prob: 0.0801), Real: no_exitoso
#   Ejemplo 34605: exitoso (prob: 0.9938), Real: exitoso
#   Ejemplo 34606: exitoso (prob: 0.9894), Real: exitoso
#   Ejemplo 34607: exitoso (prob: 0.9576), Real: exitoso
#   Ejemplo 34608: exitoso (prob: 0.9606), Real: exitoso
#   Ejemplo 34609: exitoso (prob: 0.9769), Real: exitoso
#   Ejemplo 34610: no_exitoso (prob: 0.2307), Real: no_exitoso
#   Ejemplo 34611: exitoso (prob: 0.9109), Real: exitoso
#   Ejemplo 34612: no_exitoso (prob: 0.2445), Real: no_exitoso
#   Ejemplo 34613: exitoso (prob: 0.6577), Real: exitoso
#   Ejemplo 34614: exitoso (prob: 0.9462), Real: exitoso
#   Ejemplo 34615: exitoso (prob: 0.9915), Real: exitoso
#   Ejemplo 34616: exitoso (prob: 0.9935), Real: exitoso
#   Ejemplo 34617: exitoso (prob: 0.7872), Real: exitoso
#   Ejemplo 34618: exitoso (prob: 0.7506), Real: exitoso
#   Ejemplo 34619: exitoso (prob: 0.9568), Real: exitoso
#   Ejemplo 34620: no_exitoso (prob: 0.1260), Real: no_exitoso
#   Ejemplo 34621: no_exitoso (prob: 0.0445), Real: no_exitoso
#   Ejemplo 34622: no_exitoso (prob: 0.0244), Real: no_exitoso
#   Ejemplo 34623: exitoso (prob: 0.8971), Real: exitoso
#   Ejemplo 34624: exitoso (prob: 0.9469), Real: exitoso
#   Ejemplo 34625: exitoso (prob: 0.9423), Real: exitoso
#   Ejemplo 34626: no_exitoso (prob: 0.0776), Real: no_exitoso
#   Ejemplo 34627: exitoso (prob: 0.8379), Real: no_exitoso
#   Ejemplo 34628: exitoso (prob: 0.8732), Real: exitoso
#   Ejemplo 34629: no_exitoso (prob: 0.0627), Real: no_exitoso
#   Ejemplo 34630: no_exitoso (prob: 0.2264), Real: no_exitoso
#   Ejemplo 34631: no_exitoso (prob: 0.0932), Real: no_exitoso
#   Ejemplo 34632: exitoso (prob: 0.6034), Real: exitoso
#   Ejemplo 34633: exitoso (prob: 0.8931), Real: exitoso
#   Ejemplo 34634: no_exitoso (prob: 0.3705), Real: exitoso
#   Ejemplo 34635: exitoso (prob: 0.9822), Real: exitoso
#   Ejemplo 34636: no_exitoso (prob: 0.1448), Real: no_exitoso
#   Ejemplo 34637: no_exitoso (prob: 0.1077), Real: exitoso
#   Ejemplo 34638: no_exitoso (prob: 0.1875), Real: no_exitoso
#   Ejemplo 34639: no_exitoso (prob: 0.0356), Real: no_exitoso
#   Ejemplo 34640: exitoso (prob: 0.8793), Real: exitoso
#   Ejemplo 34641: exitoso (prob: 0.5423), Real: no_exitoso
#   Ejemplo 34642: no_exitoso (prob: 0.4346), Real: exitoso
#   Ejemplo 34643: exitoso (prob: 0.7087), Real: exitoso
#   Ejemplo 34644: exitoso (prob: 0.5763), Real: exitoso
#   Ejemplo 34645: no_exitoso (prob: 0.2625), Real: no_exitoso
#   Ejemplo 34646: exitoso (prob: 0.9169), Real: exitoso
#   Ejemplo 34647: exitoso (prob: 0.8378), Real: exitoso
#   Ejemplo 34648: exitoso (prob: 0.7960), Real: no_exitoso
#   Ejemplo 34649: exitoso (prob: 0.8402), Real: exitoso
#   Ejemplo 34650: exitoso (prob: 0.8869), Real: no_exitoso
#   Ejemplo 34651: no_exitoso (prob: 0.3760), Real: no_exitoso
#   Ejemplo 34652: exitoso (prob: 0.8334), Real: no_exitoso
#   Ejemplo 34653: exitoso (prob: 0.9462), Real: no_exitoso
#   Ejemplo 34654: exitoso (prob: 0.7518), Real: exitoso
#   Ejemplo 34655: no_exitoso (prob: 0.1446), Real: no_exitoso
#   Ejemplo 34656: no_exitoso (prob: 0.4064), Real: exitoso
#   Ejemplo 34657: exitoso (prob: 0.6668), Real: exitoso
#   Ejemplo 34658: no_exitoso (prob: 0.0194), Real: no_exitoso
#   Ejemplo 34659: exitoso (prob: 0.9839), Real: exitoso
#   Ejemplo 34660: no_exitoso (prob: 0.0233), Real: no_exitoso
#   Ejemplo 34661: exitoso (prob: 0.9932), Real: exitoso
#   Ejemplo 34662: no_exitoso (prob: 0.2456), Real: no_exitoso
#   Ejemplo 34663: no_exitoso (prob: 0.0318), Real: no_exitoso
#   Ejemplo 34664: no_exitoso (prob: 0.4021), Real: no_exitoso
#   Ejemplo 34665: exitoso (prob: 0.8937), Real: exitoso
#   Ejemplo 34666: no_exitoso (prob: 0.1074), Real: no_exitoso
#   Ejemplo 34667: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 34668: no_exitoso (prob: 0.0251), Real: no_exitoso
#   Ejemplo 34669: no_exitoso (prob: 0.0200), Real: no_exitoso
#   Ejemplo 34670: no_exitoso (prob: 0.0316), Real: no_exitoso
#   Ejemplo 34671: no_exitoso (prob: 0.1470), Real: no_exitoso
#   Ejemplo 34672: exitoso (prob: 0.8529), Real: exitoso
#   Ejemplo 34673: no_exitoso (prob: 0.0876), Real: no_exitoso
#   Ejemplo 34674: exitoso (prob: 0.9592), Real: no_exitoso
#   Ejemplo 34675: no_exitoso (prob: 0.3665), Real: no_exitoso
#   Ejemplo 34676: exitoso (prob: 0.7616), Real: exitoso
#   Ejemplo 34677: no_exitoso (prob: 0.1075), Real: no_exitoso
#   Ejemplo 34678: no_exitoso (prob: 0.4403), Real: no_exitoso
#   Ejemplo 34679: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 34680: exitoso (prob: 0.9869), Real: exitoso
#   Ejemplo 34681: exitoso (prob: 0.9317), Real: exitoso
#   Ejemplo 34682: no_exitoso (prob: 0.0460), Real: no_exitoso
#   Ejemplo 34683: exitoso (prob: 0.7404), Real: no_exitoso
#   Ejemplo 34684: exitoso (prob: 0.7440), Real: exitoso
#   Ejemplo 34685: no_exitoso (prob: 0.2844), Real: no_exitoso
#   Ejemplo 34686: exitoso (prob: 0.6062), Real: exitoso
#   Ejemplo 34687: no_exitoso (prob: 0.3586), Real: no_exitoso
#   Ejemplo 34688: exitoso (prob: 0.9273), Real: exitoso
#   Ejemplo 34689: no_exitoso (prob: 0.0267), Real: no_exitoso
#   Ejemplo 34690: no_exitoso (prob: 0.4145), Real: exitoso
#   Ejemplo 34691: exitoso (prob: 0.9839), Real: exitoso
#   Ejemplo 34692: no_exitoso (prob: 0.2129), Real: no_exitoso
#   Ejemplo 34693: no_exitoso (prob: 0.1334), Real: no_exitoso
#   Ejemplo 34694: no_exitoso (prob: 0.0329), Real: no_exitoso
#   Ejemplo 34695: exitoso (prob: 0.9394), Real: exitoso
#   Ejemplo 34696: exitoso (prob: 0.9385), Real: exitoso
#   Ejemplo 34697: no_exitoso (prob: 0.0176), Real: no_exitoso
#   Ejemplo 34698: no_exitoso (prob: 0.1301), Real: no_exitoso
#   Ejemplo 34699: no_exitoso (prob: 0.2646), Real: no_exitoso
#   Ejemplo 34700: no_exitoso (prob: 0.0732), Real: no_exitoso
#   Ejemplo 34701: exitoso (prob: 0.8403), Real: exitoso
#   Ejemplo 34702: no_exitoso (prob: 0.4327), Real: no_exitoso
#   Ejemplo 34703: no_exitoso (prob: 0.2099), Real: no_exitoso
#   Ejemplo 34704: exitoso (prob: 0.8805), Real: exitoso
#   Ejemplo 34705: no_exitoso (prob: 0.1924), Real: no_exitoso
#   Ejemplo 34706: exitoso (prob: 0.6304), Real: no_exitoso
#   Ejemplo 34707: exitoso (prob: 0.9254), Real: exitoso
#   Ejemplo 34708: exitoso (prob: 0.9867), Real: exitoso
#   Ejemplo 34709: no_exitoso (prob: 0.0209), Real: no_exitoso
#   Ejemplo 34710: no_exitoso (prob: 0.4709), Real: exitoso
#   Ejemplo 34711: exitoso (prob: 0.9693), Real: exitoso
#   Ejemplo 34712: no_exitoso (prob: 0.4415), Real: exitoso
#   Ejemplo 34713: no_exitoso (prob: 0.0961), Real: no_exitoso
#   Ejemplo 34714: no_exitoso (prob: 0.1005), Real: no_exitoso
#   Ejemplo 34715: exitoso (prob: 0.5157), Real: no_exitoso
#   Ejemplo 34716: no_exitoso (prob: 0.1303), Real: no_exitoso
#   Ejemplo 34717: no_exitoso (prob: 0.0220), Real: no_exitoso
#   Ejemplo 34718: exitoso (prob: 0.9404), Real: exitoso
#   Ejemplo 34719: no_exitoso (prob: 0.0771), Real: no_exitoso
#   Ejemplo 34720: exitoso (prob: 0.8711), Real: exitoso
#   Ejemplo 34721: no_exitoso (prob: 0.0225), Real: no_exitoso
#   Ejemplo 34722: no_exitoso (prob: 0.0148), Real: no_exitoso
#   Ejemplo 34723: exitoso (prob: 0.9371), Real: no_exitoso
#   Ejemplo 34724: exitoso (prob: 0.9927), Real: exitoso
#   Ejemplo 34725: exitoso (prob: 0.7661), Real: exitoso
#   Ejemplo 34726: no_exitoso (prob: 0.0267), Real: no_exitoso
#   Ejemplo 34727: exitoso (prob: 0.9870), Real: exitoso
#   Ejemplo 34728: no_exitoso (prob: 0.0336), Real: no_exitoso
#   Ejemplo 34729: exitoso (prob: 0.9938), Real: exitoso
#   Ejemplo 34730: no_exitoso (prob: 0.3110), Real: no_exitoso
#   Ejemplo 34731: no_exitoso (prob: 0.0144), Real: no_exitoso
#   Ejemplo 34732: exitoso (prob: 0.9927), Real: exitoso
#   Ejemplo 34733: exitoso (prob: 0.8595), Real: exitoso
#   Ejemplo 34734: no_exitoso (prob: 0.0191), Real: no_exitoso
#   Ejemplo 34735: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 34736: no_exitoso (prob: 0.3793), Real: no_exitoso
#   Ejemplo 34737: exitoso (prob: 0.9454), Real: exitoso
#   Ejemplo 34738: no_exitoso (prob: 0.0371), Real: no_exitoso
#   Ejemplo 34739: no_exitoso (prob: 0.1052), Real: no_exitoso
#   Ejemplo 34740: exitoso (prob: 0.9047), Real: exitoso
#   Ejemplo 34741: exitoso (prob: 0.8891), Real: exitoso
#   Ejemplo 34742: no_exitoso (prob: 0.3507), Real: exitoso
#   Ejemplo 34743: no_exitoso (prob: 0.1005), Real: no_exitoso
#   Ejemplo 34744: no_exitoso (prob: 0.0150), Real: no_exitoso
#   Ejemplo 34745: exitoso (prob: 0.6598), Real: exitoso
#   Ejemplo 34746: exitoso (prob: 0.5835), Real: exitoso
#   Ejemplo 34747: exitoso (prob: 0.9460), Real: exitoso
#   Ejemplo 34748: exitoso (prob: 0.9661), Real: exitoso
#   Ejemplo 34749: no_exitoso (prob: 0.4145), Real: exitoso
#   Ejemplo 34750: no_exitoso (prob: 0.3815), Real: no_exitoso
#   Ejemplo 34751: no_exitoso (prob: 0.3090), Real: exitoso
#   Ejemplo 34752: no_exitoso (prob: 0.0221), Real: no_exitoso
#   Ejemplo 34753: exitoso (prob: 0.9578), Real: exitoso
#   Ejemplo 34754: exitoso (prob: 0.8010), Real: exitoso
#   Ejemplo 34755: exitoso (prob: 0.9931), Real: exitoso
#   Ejemplo 34756: no_exitoso (prob: 0.3200), Real: no_exitoso
#   Ejemplo 34757: no_exitoso (prob: 0.2080), Real: no_exitoso
#   Ejemplo 34758: no_exitoso (prob: 0.0264), Real: no_exitoso
#   Ejemplo 34759: no_exitoso (prob: 0.0160), Real: no_exitoso
#   Ejemplo 34760: exitoso (prob: 0.7629), Real: exitoso
#   Ejemplo 34761: no_exitoso (prob: 0.1182), Real: no_exitoso
#   Ejemplo 34762: no_exitoso (prob: 0.1398), Real: no_exitoso
#   Ejemplo 34763: no_exitoso (prob: 0.0225), Real: exitoso
#   Ejemplo 34764: exitoso (prob: 0.9546), Real: no_exitoso
#   Ejemplo 34765: no_exitoso (prob: 0.0926), Real: no_exitoso
#   Ejemplo 34766: no_exitoso (prob: 0.1199), Real: no_exitoso
#   Ejemplo 34767: exitoso (prob: 0.9926), Real: exitoso
#   Ejemplo 34768: exitoso (prob: 0.9876), Real: exitoso
#   Ejemplo 34769: no_exitoso (prob: 0.3901), Real: exitoso
#   Ejemplo 34770: exitoso (prob: 0.9934), Real: exitoso
#   Ejemplo 34771: no_exitoso (prob: 0.4204), Real: exitoso
#   Ejemplo 34772: exitoso (prob: 0.7449), Real: exitoso
#   Ejemplo 34773: no_exitoso (prob: 0.2022), Real: exitoso
#   Ejemplo 34774: no_exitoso (prob: 0.1602), Real: no_exitoso
#   Ejemplo 34775: no_exitoso (prob: 0.2625), Real: no_exitoso
#   Ejemplo 34776: exitoso (prob: 0.8529), Real: exitoso
#   Ejemplo 34777: exitoso (prob: 0.9870), Real: exitoso
#   Ejemplo 34778: no_exitoso (prob: 0.0338), Real: no_exitoso
#   Ejemplo 34779: exitoso (prob: 0.7725), Real: exitoso
#   Ejemplo 34780: exitoso (prob: 0.9835), Real: exitoso
#   Ejemplo 34781: no_exitoso (prob: 0.0516), Real: no_exitoso
#   Ejemplo 34782: exitoso (prob: 0.9870), Real: exitoso
#   Ejemplo 34783: exitoso (prob: 0.6668), Real: no_exitoso
#   Ejemplo 34784: exitoso (prob: 0.9701), Real: exitoso
#   Ejemplo 34785: exitoso (prob: 0.9822), Real: exitoso
#   Ejemplo 34786: exitoso (prob: 0.9935), Real: exitoso
#   Ejemplo 34787: no_exitoso (prob: 0.1606), Real: exitoso
#   Ejemplo 34788: no_exitoso (prob: 0.0778), Real: no_exitoso
#   Ejemplo 34789: exitoso (prob: 0.8534), Real: exitoso
#   Ejemplo 34790: no_exitoso (prob: 0.0348), Real: no_exitoso
#   Ejemplo 34791: exitoso (prob: 0.8558), Real: exitoso
#   Ejemplo 34792: no_exitoso (prob: 0.3070), Real: exitoso
#   Ejemplo 34793: exitoso (prob: 0.9867), Real: exitoso
#   Ejemplo 34794: no_exitoso (prob: 0.0471), Real: no_exitoso
#   Ejemplo 34795: exitoso (prob: 0.9870), Real: exitoso
#   Ejemplo 34796: exitoso (prob: 0.9447), Real: exitoso
#   Ejemplo 34797: exitoso (prob: 0.6668), Real: no_exitoso
#   Ejemplo 34798: exitoso (prob: 0.5395), Real: exitoso
#   Ejemplo 34799: exitoso (prob: 0.7995), Real: exitoso
#   Ejemplo 34800: exitoso (prob: 0.9463), Real: no_exitoso
#   Ejemplo 34801: no_exitoso (prob: 0.0330), Real: no_exitoso
#   Ejemplo 34802: no_exitoso (prob: 0.0275), Real: no_exitoso
#   Ejemplo 34803: no_exitoso (prob: 0.2099), Real: no_exitoso
#   Ejemplo 34804: exitoso (prob: 0.9576), Real: exitoso
#   Ejemplo 34805: exitoso (prob: 0.8558), Real: no_exitoso
#   Ejemplo 34806: no_exitoso (prob: 0.2879), Real: no_exitoso
#   Ejemplo 34807: no_exitoso (prob: 0.1218), Real: no_exitoso
#   Ejemplo 34808: exitoso (prob: 0.7741), Real: exitoso
#   Ejemplo 34809: exitoso (prob: 0.9303), Real: exitoso
#   Ejemplo 34810: no_exitoso (prob: 0.3065), Real: exitoso
#   Ejemplo 34811: no_exitoso (prob: 0.3808), Real: exitoso
#   Ejemplo 34812: exitoso (prob: 0.8595), Real: exitoso
#   Ejemplo 34813: no_exitoso (prob: 0.2251), Real: no_exitoso
#   Ejemplo 34814: exitoso (prob: 0.9126), Real: exitoso
#   Ejemplo 34815: no_exitoso (prob: 0.0652), Real: exitoso
#   Ejemplo 34816: exitoso (prob: 0.8379), Real: exitoso
#   Ejemplo 34817: exitoso (prob: 0.5676), Real: exitoso

# %%
df_balanced[categorical_columns].iloc[18:19]
# Out:
#    cole_depto_ubicacion cole_jornada cole_naturaleza  \
# 18              BOLIVAR       MAÑANA      NO OFICIAL
#
#                fami_educacionmadre             fami_educacionpadre  \
# 18  Educación profesional completa  Educación profesional completa
#
#    fami_estratovivienda
# 18            Estrato 3
