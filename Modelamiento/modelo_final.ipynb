# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
def create_improved_model(input_dim):
    """
    Crear un modelo mejorado
    """
    model = Sequential([
        Dense(64, activation='relu', input_dim=input_dim,
              kernel_initializer='glorot_uniform'),
        Dropout(0.3),
        Dense(32, activation='relu',
              kernel_initializer='glorot_uniform'),
        Dropout(0.3),
        Dense(1, activation='sigmoid',
              kernel_initializer='glorot_uniform')
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
def train_and_evaluate_model(model, X_train, y_train, X_test, y_test, class_weights, model_name="Modelo"):
    """
    Entrenar y evaluar modelo
    """
    print(f"Entrenando {model_name}")
    
    # Callbacks para monitorear el entrenamiento
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', 
        factor=0.2, 
        patience=10, 
        min_lr=0.0001,
        verbose=1
    )
    
    # Entrenar modelo
    history = model.fit(
        X_train, y_train,
        class_weight=class_weights, 
        validation_data=(X_test, y_test),
        epochs=50,
        batch_size=32,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    
    # Evaluar modelo
    print(f"\nEvluación {model_name}")
    
    # Predicciones
    y_pred_prob = model.predict(X_test, verbose=0)
    y_pred = (y_pred_prob > 0.5).astype(int).flatten()
    
    # Estadísticas de probabilidades
    print(f"Estadísticas de probabilidades:")
    print(f"  Min: {y_pred_prob.min():.6f}")
    print(f"  Max: {y_pred_prob.max():.6f}")
    print(f"  Mean: {y_pred_prob.mean():.6f}")
    print(f"  Std: {y_pred_prob.std():.6f}")
    print(f"  Mediana: {np.median(y_pred_prob):.6f}")
    
    # Distribución de predicciones
    print(f"\nDistribución de predicciones:")
    unique, counts = np.unique(y_pred, return_counts=True)
    for val, count in zip(unique, counts):
        label = "exitoso" if val == 1 else "no_exitoso"
        print(f"  {label}: {count}")
    
    # Matriz de confusión
    print(f"\nMatriz de confusión:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    
    # Reporte de clasificación
    print(f"\nReporte de clasificación:")
    print(classification_report(y_test, y_pred, target_names=['no_exitoso', 'exitoso']))
    
    # Verificar pesos del modelo
    print(f"\nAnálisis de pesos:")
    for i, layer in enumerate(model.layers):
        if hasattr(layer, 'get_weights') and layer.get_weights():
            weights = layer.get_weights()[0]
            print(f"  Capa {i}: shape={weights.shape}, rango=[{weights.min():.6f}, {weights.max():.6f}]")
    
    return history, y_pred_prob

# %%
# Cargar datos
df = pd.read_csv("../Datos2011Limipios.csv")
print(f"Datos originales: {df.shape}")
print(f"Distribución original:\n{df['resultado'].value_counts()}")
# Out:
# Datos originales: (494094, 29)
# Distribución original:
# resultado
# no_exitoso    476685
# exitoso        17409
# Name: count, dtype: int64

# %%
def balancear_dataframe_simple(df, columna_resultado):
    exitosos = df[df[columna_resultado] == 'exitoso']
    no_exitosos = df[df[columna_resultado] == 'no_exitoso']
    
    min_count = min(len(exitosos), len(no_exitosos))
    
    exitosos_sample = exitosos.sample(min_count, random_state=42)
    no_exitosos_sample = no_exitosos.sample(min_count*5, random_state=42)
    
    return pd.concat([exitosos_sample, no_exitosos_sample]).sample(frac=1, random_state=42).reset_index(drop=True)

df = balancear_dataframe_simple(df, 'resultado')
print(f"Datos balanceados: {df.shape}")
print(f"Distribución balanceada:\n{df['resultado'].value_counts()}")
# Out:
# Datos balanceados: (104454, 29)
# Distribución balanceada:
# resultado
# no_exitoso    87045
# exitoso       17409
# Name: count, dtype: int64

# %%
categorical_columns = ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 
                       'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
existing_categorical = [col for col in categorical_columns if col in df.columns]
print(f"Columnas categóricas disponibles: {existing_categorical}")
# Out:
# Columnas categóricas disponibles: ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
df_processed = df.copy()

# %%
encoders = {}
for col in existing_categorical:
    print(f"Procesando {col}...")
    # Llenar valores nulos
    df_processed[col] = df_processed[col].fillna('unknown')
    
    # Codificar con LabelEncoder
    le = LabelEncoder()
    df_processed[col] = le.fit_transform(df_processed[col].astype(str))
    encoders[col] = le
    
    print(f"  {col}: {len(le.classes_)} clases únicas")
# Out:
# Procesando cole_depto_ubicacion...
#   cole_depto_ubicacion: 34 clases únicas
# Procesando cole_jornada...
#   cole_jornada: 6 clases únicas
# Procesando cole_naturaleza...
#   cole_naturaleza: 2 clases únicas
# Procesando fami_educacionmadre...
#   fami_educacionmadre: 11 clases únicas
# Procesando fami_educacionpadre...
#   fami_educacionpadre: 11 clases únicas
# Procesando fami_estratovivienda...
#   fami_estratovivienda: 6 clases únicas

# %%
feature_columns = existing_categorical
X = df_processed[feature_columns].copy()
y = df_processed['resultado'].map({'no_exitoso': 0, 'exitoso': 1})

print(f"\nFeatures finales: {X.shape}")
print(f"Columnas: {list(X.columns)}")
# Out:
# Features finales: (104454, 6)
# Columnas: ['cole_depto_ubicacion', 'cole_jornada', 'cole_naturaleza', 'fami_educacionmadre', 'fami_educacionpadre', 'fami_estratovivienda']

# %%
from sklearn.utils import class_weight
# Asignación de pesos a las clases para evitar el sesgo
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y), y=y)
class_weights = {cls: weight for cls, weight in zip(np.unique(y), weights)}
class_weights
# Out:
# {np.int64(0): np.float64(0.6), np.int64(1): np.float64(3.0)}

# %%
scaler = StandardScaler()
X_scaled = pd.DataFrame(
    scaler.fit_transform(X), 
    columns=X.columns, 
    index=X.index
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print(f"\nConjuntos de entrenamiento y prueba:")
print(f"  Train: {X_train.shape}, distribución: {np.bincount(y_train)}")
print(f"  Test: {X_test.shape}, distribución: {np.bincount(y_test)}")
# Out:
# Conjuntos de entrenamiento y prueba:
#   Train: (83563, 6), distribución: [69636 13927]
#   Test: (20891, 6), distribución: [17409  3482]

# %%
improved_model = create_improved_model(X_train.shape[1])
improved_history, improved_probs = train_and_evaluate_model(
    improved_model, X_train, y_train, X_test, y_test, class_weights, "Mejorado"
)
    
# Guardar el mejor modelo
best_model = improved_model
best_probs = improved_probs
# Out:
# Entrenando Mejorado
# Epoch 1/50
# c:\Users\sofia\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8364 - loss: 0.4042 - val_accuracy: 0.8538 - val_loss: 0.3553 - learning_rate: 0.0010
# Epoch 2/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8539 - loss: 0.3692 - val_accuracy: 0.8546 - val_loss: 0.3324 - learning_rate: 0.0010
# Epoch 3/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8574 - loss: 0.3596 - val_accuracy: 0.8522 - val_loss: 0.3620 - learning_rate: 0.0010
# Epoch 4/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8569 - loss: 0.3594 - val_accuracy: 0.8547 - val_loss: 0.3475 - learning_rate: 0.0010
# Epoch 5/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8556 - loss: 0.3592 - val_accuracy: 0.8579 - val_loss: 0.3447 - learning_rate: 0.0010
# Epoch 6/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8579 - loss: 0.3538 - val_accuracy: 0.8523 - val_loss: 0.3574 - learning_rate: 0.0010
# Epoch 7/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8564 - loss: 0.3543 - val_accuracy: 0.8599 - val_loss: 0.3415 - learning_rate: 0.0010
# Epoch 8/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8602 - loss: 0.3526 - val_accuracy: 0.8508 - val_loss: 0.3469 - learning_rate: 0.0010
# Epoch 9/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8571 - loss: 0.3469 - val_accuracy: 0.8512 - val_loss: 0.3474 - learning_rate: 0.0010
# Epoch 10/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8556 - loss: 0.3552 - val_accuracy: 0.8623 - val_loss: 0.3318 - learning_rate: 0.0010
# Epoch 11/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8593 - loss: 0.3477 - val_accuracy: 0.8556 - val_loss: 0.3424 - learning_rate: 0.0010
# Epoch 12/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8582 - loss: 0.3545 - val_accuracy: 0.8480 - val_loss: 0.3515 - learning_rate: 0.0010
# Epoch 13/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8561 - loss: 0.3491 - val_accuracy: 0.8627 - val_loss: 0.3287 - learning_rate: 0.0010
# Epoch 14/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8574 - loss: 0.3517 - val_accuracy: 0.8615 - val_loss: 0.3337 - learning_rate: 0.0010
# Epoch 15/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8621 - loss: 0.3392 - val_accuracy: 0.8594 - val_loss: 0.3470 - learning_rate: 0.0010
# Epoch 16/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8575 - loss: 0.3467 - val_accuracy: 0.8565 - val_loss: 0.3389 - learning_rate: 0.0010
# Epoch 17/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8580 - loss: 0.3521 - val_accuracy: 0.8582 - val_loss: 0.3352 - learning_rate: 0.0010
# Epoch 18/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8578 - loss: 0.3514 - val_accuracy: 0.8521 - val_loss: 0.3445 - learning_rate: 0.0010
# Epoch 19/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8565 - loss: 0.3507 - val_accuracy: 0.8467 - val_loss: 0.3534 - learning_rate: 0.0010
# Epoch 20/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8541 - loss: 0.3535 - val_accuracy: 0.8664 - val_loss: 0.3311 - learning_rate: 0.0010
# Epoch 21/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8602 - loss: 0.3546 - val_accuracy: 0.8562 - val_loss: 0.3364 - learning_rate: 0.0010
# Epoch 22/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8576 - loss: 0.3478 - val_accuracy: 0.8590 - val_loss: 0.3441 - learning_rate: 0.0010
# Epoch 23/50
# 2609/2612 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8555 - loss: 0.3514
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8555 - loss: 0.3514 - val_accuracy: 0.8566 - val_loss: 0.3380 - learning_rate: 0.0010
# Epoch 24/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8551 - loss: 0.3503 - val_accuracy: 0.8576 - val_loss: 0.3372 - learning_rate: 2.0000e-04
# Epoch 25/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8580 - loss: 0.3485 - val_accuracy: 0.8575 - val_loss: 0.3412 - learning_rate: 2.0000e-04
# Epoch 26/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8581 - loss: 0.3517 - val_accuracy: 0.8597 - val_loss: 0.3297 - learning_rate: 2.0000e-04
# Epoch 27/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8594 - loss: 0.3431 - val_accuracy: 0.8568 - val_loss: 0.3425 - learning_rate: 2.0000e-04
# Epoch 28/50
# 2612/2612 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8564 - loss: 0.3456 - val_accuracy: 0.8604 - val_loss: 0.3325 - learning_rate: 2.0000e-04
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 13.
#
# Evluación Mejorado
# Estadísticas de probabilidades:
#   Min: 0.012768
#   Max: 0.989850
#   Mean: 0.298928
#   Std: 0.319584
#   Mediana: 0.136221
#
# Distribución de predicciones:
#   no_exitoso: 15643
#   exitoso: 5248
#
# Matriz de confusión:
# [[15092  2317]
#  [  551  2931]]
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#   no_exitoso       0.96      0.87      0.91     17409
#      exitoso       0.56      0.84      0.67      3482
#
#     accuracy                           0.86     20891
#    macro avg       0.76      0.85      0.79     20891
# weighted avg       0.90      0.86      0.87     20891
#
#
# Análisis de pesos:
#   Capa 0: shape=(6, 64), rango=[-0.505246, 0.591646]
#   Capa 2: shape=(64, 32), rango=[-1.179717, 0.494820]
#   Capa 4: shape=(32, 1), rango=[-0.362104, 0.288990]

# %%
best_model.save('modelo.keras')
# Guardar información de preprocesamiento
import pickle
preprocessing_info = {
    'feature_columns': feature_columns,
    'encoders': encoders,
    'scaler': scaler,
    'categorical_columns': existing_categorical
    }
    
with open('info_modelo.pkl', 'wb') as f:
    pickle.dump(preprocessing_info, f)

# %%
def test_predictions_on_sample(model_path, preprocessing_path, sample_data):
    """
    Probar predicciones en datos de muestra
    """
    model = tf.keras.models.load_model(model_path)
    
    with open(preprocessing_path, 'rb') as f:
        prep_info = pickle.load(f)
    
    # Procesar datos
    sample_processed = sample_data.copy()
    
    for col in prep_info['categorical_columns']:
        if col in sample_processed.columns:
            sample_processed[col] = sample_processed[col].fillna('unknown')
            le = prep_info['encoders'][col]
            # Manejar valores no vistos
            sample_processed[col] = sample_processed[col].astype(str).apply(
                lambda x: x if x in le.classes_ else le.classes_[0]
            )
            sample_processed[col] = le.transform(sample_processed[col])
    
    # Normalizar
    sample_scaled = prep_info['scaler'].transform(sample_processed[prep_info['feature_columns']])
    
    # Predecir
    probs = model.predict(sample_scaled, verbose=0)
    preds = (probs > 0.5).astype(int)
    
    return probs, preds

# %%
sample_data = df[existing_categorical].iloc[:100]
    
try:
    probs, preds = test_predictions_on_sample(
        'modelo.keras',
        'info_modelo.pkl',
        sample_data
        )
        
    print("Predicciones en muestra:")
    for i, (prob, pred) in enumerate(zip(probs.flatten(), preds.flatten())):
        real = df['resultado'].iloc[i]
        pred_label = 'exitoso' if pred == 1 else 'no_exitoso'
        print(f"  Ejemplo {i+1}: {pred_label} (prob: {prob:.4f}), Real: {real}")
            
except Exception as e:
    print(f"Error al probar predicciones: {e}")
# Out:
# Predicciones en muestra:
#   Ejemplo 1: no_exitoso (prob: 0.2659), Real: no_exitoso
#   Ejemplo 2: exitoso (prob: 0.9232), Real: no_exitoso
#   Ejemplo 3: no_exitoso (prob: 0.1132), Real: no_exitoso
#   Ejemplo 4: exitoso (prob: 0.6310), Real: exitoso
#   Ejemplo 5: no_exitoso (prob: 0.3142), Real: no_exitoso
#   Ejemplo 6: exitoso (prob: 0.9275), Real: no_exitoso
#   Ejemplo 7: exitoso (prob: 0.6275), Real: no_exitoso
#   Ejemplo 8: no_exitoso (prob: 0.1033), Real: no_exitoso
#   Ejemplo 9: no_exitoso (prob: 0.0208), Real: no_exitoso
#   Ejemplo 10: no_exitoso (prob: 0.2280), Real: no_exitoso
#   Ejemplo 11: no_exitoso (prob: 0.0159), Real: no_exitoso
#   Ejemplo 12: no_exitoso (prob: 0.2289), Real: no_exitoso
#   Ejemplo 13: no_exitoso (prob: 0.3005), Real: no_exitoso
#   Ejemplo 14: exitoso (prob: 0.9275), Real: exitoso
#   Ejemplo 15: no_exitoso (prob: 0.0572), Real: no_exitoso
#   Ejemplo 16: no_exitoso (prob: 0.1992), Real: no_exitoso
#   Ejemplo 17: exitoso (prob: 0.8343), Real: exitoso
#   Ejemplo 18: exitoso (prob: 0.5455), Real: no_exitoso
#   Ejemplo 19: exitoso (prob: 0.8499), Real: no_exitoso
#   Ejemplo 20: no_exitoso (prob: 0.1873), Real: no_exitoso
#   Ejemplo 21: no_exitoso (prob: 0.0648), Real: no_exitoso
#   Ejemplo 22: no_exitoso (prob: 0.1378), Real: no_exitoso
#   Ejemplo 23: no_exitoso (prob: 0.0236), Real: no_exitoso
#   Ejemplo 24: exitoso (prob: 0.9873), Real: exitoso
#   Ejemplo 25: no_exitoso (prob: 0.0826), Real: no_exitoso
#   Ejemplo 26: exitoso (prob: 0.7241), Real: no_exitoso
#   Ejemplo 27: no_exitoso (prob: 0.0302), Real: no_exitoso
#   Ejemplo 28: no_exitoso (prob: 0.1525), Real: no_exitoso
#   Ejemplo 29: no_exitoso (prob: 0.0500), Real: no_exitoso
#   Ejemplo 30: no_exitoso (prob: 0.0175), Real: no_exitoso
#   Ejemplo 31: no_exitoso (prob: 0.1217), Real: no_exitoso
#   Ejemplo 32: no_exitoso (prob: 0.2671), Real: no_exitoso
#   Ejemplo 33: no_exitoso (prob: 0.0247), Real: no_exitoso
#   Ejemplo 34: no_exitoso (prob: 0.1070), Real: no_exitoso
#   Ejemplo 35: no_exitoso (prob: 0.0208), Real: no_exitoso
#   Ejemplo 36: no_exitoso (prob: 0.0979), Real: no_exitoso
#   Ejemplo 37: no_exitoso (prob: 0.3382), Real: no_exitoso
#   Ejemplo 38: no_exitoso (prob: 0.1183), Real: no_exitoso
#   Ejemplo 39: no_exitoso (prob: 0.1120), Real: no_exitoso
#   Ejemplo 40: no_exitoso (prob: 0.1556), Real: no_exitoso
#   Ejemplo 41: no_exitoso (prob: 0.0927), Real: no_exitoso
#   Ejemplo 42: no_exitoso (prob: 0.0356), Real: no_exitoso
#   Ejemplo 43: no_exitoso (prob: 0.0247), Real: no_exitoso
#   Ejemplo 44: exitoso (prob: 0.8218), Real: exitoso
#   Ejemplo 45: exitoso (prob: 0.5466), Real: no_exitoso
#   Ejemplo 46: no_exitoso (prob: 0.0203), Real: no_exitoso
#   Ejemplo 47: exitoso (prob: 0.7184), Real: no_exitoso
#   Ejemplo 48: no_exitoso (prob: 0.3819), Real: no_exitoso
#   Ejemplo 49: no_exitoso (prob: 0.2054), Real: no_exitoso
#   Ejemplo 50: no_exitoso (prob: 0.0208), Real: no_exitoso
#   Ejemplo 51: exitoso (prob: 0.9565), Real: exitoso
#   Ejemplo 52: no_exitoso (prob: 0.0893), Real: no_exitoso
#   Ejemplo 53: no_exitoso (prob: 0.0233), Real: no_exitoso
#   Ejemplo 54: no_exitoso (prob: 0.0253), Real: no_exitoso
#   Ejemplo 55: exitoso (prob: 0.9873), Real: exitoso
#   Ejemplo 56: no_exitoso (prob: 0.2999), Real: no_exitoso
#   Ejemplo 57: no_exitoso (prob: 0.1281), Real: no_exitoso
#   Ejemplo 58: exitoso (prob: 0.9235), Real: exitoso
#   Ejemplo 59: no_exitoso (prob: 0.2519), Real: no_exitoso
#   Ejemplo 60: no_exitoso (prob: 0.0311), Real: no_exitoso
#   Ejemplo 61: exitoso (prob: 0.8151), Real: no_exitoso
#   Ejemplo 62: no_exitoso (prob: 0.0340), Real: no_exitoso
#   Ejemplo 63: exitoso (prob: 0.9884), Real: exitoso
#   Ejemplo 64: no_exitoso (prob: 0.0534), Real: no_exitoso
#   Ejemplo 65: no_exitoso (prob: 0.0800), Real: no_exitoso
#   Ejemplo 66: no_exitoso (prob: 0.0301), Real: no_exitoso
#   Ejemplo 67: no_exitoso (prob: 0.1217), Real: no_exitoso
#   Ejemplo 68: no_exitoso (prob: 0.0290), Real: no_exitoso
#   Ejemplo 69: exitoso (prob: 0.6275), Real: no_exitoso
#   Ejemplo 70: no_exitoso (prob: 0.0179), Real: no_exitoso
#   Ejemplo 71: exitoso (prob: 0.5015), Real: no_exitoso
#   Ejemplo 72: exitoso (prob: 0.7319), Real: no_exitoso
#   Ejemplo 73: no_exitoso (prob: 0.0783), Real: no_exitoso
#   Ejemplo 74: no_exitoso (prob: 0.1322), Real: no_exitoso
#   Ejemplo 75: no_exitoso (prob: 0.0269), Real: no_exitoso
#   Ejemplo 76: no_exitoso (prob: 0.0223), Real: no_exitoso
#   Ejemplo 77: no_exitoso (prob: 0.0783), Real: no_exitoso
#   Ejemplo 78: no_exitoso (prob: 0.2075), Real: no_exitoso
#   Ejemplo 79: no_exitoso (prob: 0.0773), Real: no_exitoso
#   Ejemplo 80: no_exitoso (prob: 0.1467), Real: no_exitoso
#   Ejemplo 81: no_exitoso (prob: 0.4065), Real: no_exitoso
#   Ejemplo 82: no_exitoso (prob: 0.2885), Real: no_exitoso
#   Ejemplo 83: no_exitoso (prob: 0.0289), Real: no_exitoso
#   Ejemplo 84: exitoso (prob: 0.9357), Real: exitoso
#   Ejemplo 85: no_exitoso (prob: 0.0281), Real: no_exitoso
#   Ejemplo 86: no_exitoso (prob: 0.1192), Real: no_exitoso
#   Ejemplo 87: no_exitoso (prob: 0.0184), Real: no_exitoso
#   Ejemplo 88: no_exitoso (prob: 0.2191), Real: no_exitoso
#   Ejemplo 89: no_exitoso (prob: 0.0165), Real: exitoso
#   Ejemplo 90: no_exitoso (prob: 0.2351), Real: no_exitoso
#   Ejemplo 91: no_exitoso (prob: 0.2266), Real: no_exitoso
#   Ejemplo 92: no_exitoso (prob: 0.0371), Real: no_exitoso
#   Ejemplo 93: exitoso (prob: 0.8369), Real: no_exitoso
#   Ejemplo 94: exitoso (prob: 0.5170), Real: exitoso
#   Ejemplo 95: exitoso (prob: 0.6617), Real: exitoso
#   Ejemplo 96: no_exitoso (prob: 0.0249), Real: no_exitoso
#   Ejemplo 97: no_exitoso (prob: 0.1539), Real: no_exitoso
#   Ejemplo 98: no_exitoso (prob: 0.0365), Real: no_exitoso
#   Ejemplo 99: no_exitoso (prob: 0.1384), Real: no_exitoso
#   Ejemplo 100: no_exitoso (prob: 0.2702), Real: no_exitoso

# %%
df[categorical_columns+['resultado']].iloc[:30]
# Out:
#    cole_depto_ubicacion cole_jornada cole_naturaleza  \
# 0                BOGOTA        TARDE         OFICIAL
# 1                BOGOTA     COMPLETA      NO OFICIAL
# 2             ANTIOQUIA        NOCHE         OFICIAL
# 3                BOGOTA     COMPLETA      NO OFICIAL
# 4             SANTANDER       MAÑANA         OFICIAL
# 5                BOGOTA     COMPLETA      NO OFICIAL
# 6          CUNDINAMARCA       MAÑANA         OFICIAL
# 7             ANTIOQUIA       MAÑANA         OFICIAL
# 8               BOLIVAR       MAÑANA         OFICIAL
# 9                 VALLE       MAÑANA         OFICIAL
# 10            ANTIOQUIA        TARDE         OFICIAL
# 11               TOLIMA       MAÑANA         OFICIAL
# 12               BOGOTA        TARDE         OFICIAL
# 13               BOGOTA     COMPLETA      NO OFICIAL
# 14            RISARALDA       MAÑANA         OFICIAL
# 15            ANTIOQUIA       MAÑANA         OFICIAL
# 16               BOGOTA     COMPLETA      NO OFICIAL
# 17            RISARALDA       MAÑANA      NO OFICIAL
# 18            ATLANTICO     COMPLETA      NO OFICIAL
# 19               BOGOTA     COMPLETA         OFICIAL
# 20            ATLANTICO        TARDE         OFICIAL
# 21            ANTIOQUIA       MAÑANA         OFICIAL
# 22              BOLIVAR       MAÑANA         OFICIAL
# 23               BOGOTÁ     COMPLETA      NO OFICIAL
# 24         CUNDINAMARCA        NOCHE         OFICIAL
# 25               NARIÑO       MAÑANA      NO OFICIAL
# 26                HUILA        TARDE         OFICIAL
# 27                VALLE       MAÑANA      NO OFICIAL
# 28               BOGOTA       MAÑANA      NO OFICIAL
# 29            ANTIOQUIA        TARDE         OFICIAL
#
#                      fami_educacionmadre  \
# 0   Secundaria (Bachillerato) incompleta
# 1       Técnica o tecnológica incompleta
# 2                                No sabe
# 3         Técnica o tecnológica completa
# 4                      Primaria completa
# 5         Educación profesional completa
# 6         Educación profesional completa
# 7     Secundaria (Bachillerato) completa
# 8                    Primaria incompleta
# 9                                No sabe
# 10                   Primaria incompleta
# 11    Secundaria (Bachillerato) completa
# 12  Secundaria (Bachillerato) incompleta
# 13        Educación profesional completa
# 14    Secundaria (Bachillerato) completa
# 15                     Primaria completa
# 16        Educación profesional completa
# 17    Secundaria (Bachillerato) completa
# 18    Secundaria (Bachillerato) completa
# 19    Secundaria (Bachillerato) completa
# 20        Educación profesional completa
# 21  Secundaria (Bachillerato) incompleta
# 22    Secundaria (Bachillerato) completa
# 23        Educación profesional completa
# 24                   Primaria incompleta
# 25        Educación profesional completa
# 26  Secundaria (Bachillerato) incompleta
# 27  Secundaria (Bachillerato) incompleta
# 28  Secundaria (Bachillerato) incompleta
# 29    Secundaria (Bachillerato) completa
#
#                      fami_educacionpadre fami_estratovivienda   resultado
# 0                    Primaria incompleta            Estrato 3  no_exitoso
# 1         Educación profesional completa            Estrato 5  no_exitoso
# 2                                No sabe            Estrato 2  no_exitoso
# 3         Técnica o tecnológica completa            Estrato 3     exitoso
# 4     Secundaria (Bachillerato) completa            Estrato 3  no_exitoso
# 5         Educación profesional completa            Estrato 4  no_exitoso
# 6         Educación profesional completa            Estrato 3  no_exitoso
# 7     Secundaria (Bachillerato) completa            Estrato 2  no_exitoso
# 8                    Primaria incompleta            Estrato 1  no_exitoso
# 9                                No sabe            Estrato 2  no_exitoso
# 10                   Primaria incompleta            Estrato 1  no_exitoso
# 11    Secundaria (Bachillerato) completa            Estrato 3  no_exitoso
# 12                               Ninguno            Estrato 3  no_exitoso
# 13        Educación profesional completa            Estrato 4     exitoso
# 14                               Ninguno            Estrato 1  no_exitoso
# 15                   Primaria incompleta            Estrato 3  no_exitoso
# 16        Educación profesional completa            Estrato 3     exitoso
# 17                             Postgrado            Estrato 3  no_exitoso
# 18                             Postgrado            Estrato 4  no_exitoso
# 19                               No sabe            Estrato 2  no_exitoso
# 20        Educación profesional completa            Estrato 1  no_exitoso
# 21  Secundaria (Bachillerato) incompleta            Estrato 2  no_exitoso
# 22                     Primaria completa            Estrato 1  no_exitoso
# 23        Educación profesional completa            Estrato 6     exitoso
# 24                   Primaria incompleta            Estrato 2  no_exitoso
# 25    Secundaria (Bachillerato) completa            Estrato 3  no_exitoso
# 26  Secundaria (Bachillerato) incompleta            Estrato 1  no_exitoso
# 27    Secundaria (Bachillerato) completa            Estrato 1  no_exitoso
# 28                             Postgrado            Estrato 1  no_exitoso
# 29                     Primaria completa            Estrato 1  no_exitoso
